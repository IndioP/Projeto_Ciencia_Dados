# %% [markdown]
# <a href="https://colab.research.google.com/github/IndioP/Projeto_Ciencia_Dados/blob/main/Unificando_tabelas_de_estudo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Velocidades das Vias - http://dados.recife.pe.gov.br/dataset?q=Velocidade+das+Vias+-+Quantitativo+por+Velocidade+Média+&sort=score+desc%2C+metadata_modified+desc (2016 - 2021 / )
# * Registro de Infrações de Transito - http://dados.recife.pe.gov.br/dataset/registro-das-infracoes-de-transito (Possui dados de 2006 - 2021, porém, será coletado somente de 2015 até 2021)
# * Acidentes de Transito sem e com vítima - http://dados.recife.pe.gov.br/dataset/acidentes-de-transito-com-e-sem-vitimas   (2015 - 2020)
# * Possibilidade de Bares - https://dados.gov.br/dataset/cadastur-15

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999
pd.set_option('display.max_columns', None)  
pd.set_option('display.width', 2000)

# %% [markdown]
# # Acidentes de Transito

# %%
df_acidente_transito_15 = pd.read_csv("acidentes_transito_2015.csv", delimiter=';')
df_acidente_transito_15.columns = map(str.upper, df_acidente_transito_15.columns)

df_acidente_transito_16 = pd.read_csv("acidentes_transito_2016.csv", delimiter=';')
df_acidente_transito_16.columns = map(str.upper, df_acidente_transito_16.columns)

df_acidente_transito_17 = pd.read_csv("acidentes_transito_2017.csv", delimiter=';')
df_acidente_transito_17.columns = map(str.upper, df_acidente_transito_17.columns)

df_acidente_transito_18 = pd.read_csv("acidentes_transito_2018.csv", delimiter=';')
df_acidente_transito_18.columns = map(str.upper, df_acidente_transito_18.columns)

df_acidente_transito_19 = pd.read_csv("acidentes_transito_2019.csv", delimiter=';')
df_acidente_transito_19.columns = map(str.upper, df_acidente_transito_19.columns)

df_acidente_transito_20 = pd.read_csv("acidentes_transito_2020.csv", delimiter=';')
df_acidente_transito_20.columns = map(str.upper, df_acidente_transito_20.columns)

df_acidente_transito_21 = pd.read_csv("acidentes_transito_2021_jan.csv", delimiter=';')
df_acidente_transito_21.columns = map(str.upper, df_acidente_transito_21.columns)

print(df_acidente_transito_15.columns,'\n')
print(df_acidente_transito_16.columns,'\n')
print(df_acidente_transito_17.columns,'\n')
print(df_acidente_transito_18.columns,'\n')
print(df_acidente_transito_19.columns,'\n')
print(df_acidente_transito_20.columns,'\n')
print(df_acidente_transito_21.columns,'\n')
# Out:
# Index(['TIPO', 'SITUACAO', 'DATA', 'HORA', 'BAIRRO', 'ENDERECO', 'NUMERO', 'COMPLEMENTO', 'NATUREZA', 'DESCRICAO', 'AUTO', 'MOTO', 'CICLOM', 'CICLISTA', 'PEDESTRE', 'ONIBUS', 'CAMINHAO', 'VIATURA', 'OUTROS', 'VITIMAS'], dtype='object')
#
# Index(['DATA', 'HORA', 'NATUREZA_ACIDENTE', 'SITUACAO', 'BAIRRO', 'ENDERECO', 'NUMERO', 'DETALHE_ENDERECO_ACIDENTE', 'COMPLEMENTO', 'ENDERECO_CRUZAMENTO', 'NUMERO_CRUZAMENTO', 'REFERENCIA_CRUZAMENTO', 'BAIRRO_CRUZAMENTO', 'TIPO', 'DESCRICAO', 'AUTO', 'MOTO', 'CICLOM', 'CICLISTA', 'PEDESTRE', 'ONIBUS', 'CAMINHAO', 'VIATURA', 'OUTROS', 'VITIMAS', 'VITIMASFATAIS'], dtype='object')
#
# Index(['DATA', 'HORA', 'NATUREZA_ACIDENTE', 'SITUACAO', 'BAIRRO', 'ENDERECO', 'NUMERO', 'DETALHE_ENDERECO_ACIDENTE', 'COMPLEMENTO', 'ENDERECO_CRUZAMENTO', 'NUMERO_CRUZAMENTO', 'REFERENCIA_CRUZAMENTO', 'BAIRRO_CRUZAMENTO', 'TIPO', 'AUTO', 'MOTO', 'CICLOM', 'CICLISTA', 'PEDESTRE', 'ONIBUS', 'CAMINHAO', 'VIATURA', 'OUTROS', 'VITIMAS', 'VITIMASFATAIS'], dtype='object')
#
# ...

# %%
ac_2015 = df_acidente_transito_15.columns
ac_2016 = df_acidente_transito_16.columns
ac_2017 = df_acidente_transito_17.columns
ac_2018 = df_acidente_transito_18.columns
ac_2019 = df_acidente_transito_19.columns
ac_2020 = df_acidente_transito_20.columns
ac_2021 = df_acidente_transito_21.columns

diff_15_21 = [item for item in ac_2015 if item not in ac_2021]
diff_16_21 = [item for item in ac_2016 if item not in ac_2021]
diff_17_21 = [item for item in ac_2017 if item not in ac_2021]
diff_18_21 = [item for item in ac_2018 if item not in ac_2021]
diff_19_21 = [item for item in ac_2019 if item not in ac_2021]
diff_20_21 = [item for item in ac_2020 if item not in ac_2021]

print('2015 faltante em 2021 - ',diff_15_21,'\n')
print('2016 faltante em 2021 - ',diff_16_21,'\n')
print('2017 faltante em 2021 - ',diff_17_21,'\n')
print('2018 faltante em 2021 - ',diff_18_21,'\n')
print('2019 faltante em 2021 - ',diff_19_21,'\n')
print('2020 faltante em 2021 - ',diff_20_21,'\n')
# Out:
# 2015 faltante em 2021 -  ['NATUREZA']
#
# 2016 faltante em 2021 -  ['ENDERECO_CRUZAMENTO', 'NUMERO_CRUZAMENTO', 'REFERENCIA_CRUZAMENTO']
#
# 2017 faltante em 2021 -  ['ENDERECO_CRUZAMENTO', 'NUMERO_CRUZAMENTO', 'REFERENCIA_CRUZAMENTO']
#
# 2018 faltante em 2021 -  ['ENDERECO_CRUZAMENTO', 'NUMERO_CRUZAMENTO', 'REFERENCIA_CRUZAMENTO']
#
# 2019 faltante em 2021 -  ['ENDERECO_CRUZAMENTO', 'NUMERO_CRUZAMENTO', 'REFERENCIA_CRUZAMENTO']
#
# 2020 faltante em 2021 -  []

# %%
df_acidente_transito_21_ = df_acidente_transito_21.reindex(columns=df_acidente_transito_21.columns.tolist() + ['NATUREZA','ENDERECO_CRUZAMENTO','NUMERO_CRUZAMENTO','REFERENCIA_CRUZAMENTO'])
print('LAYOUT GERAL 2021 - ',df_acidente_transito_21_.columns)
# Out:
# LAYOUT GERAL 2021 -  Index(['DATA', 'HORA', 'NATUREZA_ACIDENTE', 'SITUACAO', 'BAIRRO', 'ENDERECO', 'NUMERO', 'DETALHE_ENDERECO_ACIDENTE', 'COMPLEMENTO', 'BAIRRO_CRUZAMENTO', 'NUM_SEMAFORO', 'SENTIDO_VIA', 'TIPO', 'DESCRICAO', 'AUTO', 'MOTO', 'CICLOM', 'CICLISTA', 'PEDESTRE', 'ONIBUS', 'CAMINHAO', 'VIATURA', 'OUTROS', 'VITIMAS', 'VITIMASFATAIS', 'ACIDENTE_VERIFICADO', 'TEMPO_CLIMA', 'SITUACAO_SEMAFORO', 'SINALIZACAO', 'CONDICAO_VIA', 'CONSERVACAO_VIA', 'PONTO_CONTROLE', 'SITUACAO_PLACA', 'VELOCIDADE_MAX_VIA', 'MAO_DIRECAO', 'DIVISAO_VIA1', 'DIVISAO_VIA2', 'DIVISAO_VIA3', 'NATUREZA', 'ENDERECO_CRUZAMENTO', 'NUMERO_CRUZAMENTO', 'REFERENCIA_CRUZAMENTO'], dtype='object')

# %% [markdown]
# Verificando o que falta entre os datasets de (2015-2020) em relação ao de 2021 (o mais atual)

# %%
#df_acidente_transito_21_
diff_21_15 = [item for item in df_acidente_transito_21_.columns if item not in ac_2015]
diff_21_16 = [item for item in df_acidente_transito_21_.columns if item not in ac_2016]
diff_21_17 = [item for item in df_acidente_transito_21_.columns if item not in ac_2017]
diff_21_18 = [item for item in df_acidente_transito_21_.columns if item not in ac_2018]
diff_21_19 = [item for item in df_acidente_transito_21_.columns if item not in ac_2019]
diff_21_20 = [item for item in df_acidente_transito_21_.columns if item not in ac_2020]

print(diff_21_15,'\n')
print(diff_21_16,'\n')
print(diff_21_17,'\n')
print(diff_21_18,'\n')
print(diff_21_19,'\n')
print(diff_21_20,'\n')
# Out:
# ['NATUREZA_ACIDENTE', 'DETALHE_ENDERECO_ACIDENTE', 'BAIRRO_CRUZAMENTO', 'NUM_SEMAFORO', 'SENTIDO_VIA', 'VITIMASFATAIS', 'ACIDENTE_VERIFICADO', 'TEMPO_CLIMA', 'SITUACAO_SEMAFORO', 'SINALIZACAO', 'CONDICAO_VIA', 'CONSERVACAO_VIA', 'PONTO_CONTROLE', 'SITUACAO_PLACA', 'VELOCIDADE_MAX_VIA', 'MAO_DIRECAO', 'DIVISAO_VIA1', 'DIVISAO_VIA2', 'DIVISAO_VIA3', 'ENDERECO_CRUZAMENTO', 'NUMERO_CRUZAMENTO', 'REFERENCIA_CRUZAMENTO']
#
# ['NUM_SEMAFORO', 'SENTIDO_VIA', 'ACIDENTE_VERIFICADO', 'TEMPO_CLIMA', 'SITUACAO_SEMAFORO', 'SINALIZACAO', 'CONDICAO_VIA', 'CONSERVACAO_VIA', 'PONTO_CONTROLE', 'SITUACAO_PLACA', 'VELOCIDADE_MAX_VIA', 'MAO_DIRECAO', 'DIVISAO_VIA1', 'DIVISAO_VIA2', 'DIVISAO_VIA3', 'NATUREZA']
#
# ['NUM_SEMAFORO', 'SENTIDO_VIA', 'DESCRICAO', 'ACIDENTE_VERIFICADO', 'TEMPO_CLIMA', 'SITUACAO_SEMAFORO', 'SINALIZACAO', 'CONDICAO_VIA', 'CONSERVACAO_VIA', 'PONTO_CONTROLE', 'SITUACAO_PLACA', 'VELOCIDADE_MAX_VIA', 'MAO_DIRECAO', 'DIVISAO_VIA1', 'DIVISAO_VIA2', 'DIVISAO_VIA3', 'NATUREZA']
#
# ...

# %% [markdown]
# Adicionando o que falta nos layouts para podermos unifica-los

# %%
df_acidente_transito_15_ = df_acidente_transito_15.reindex(columns=df_acidente_transito_15.columns.tolist() + diff_21_15)   
#df_acidente_transito_15_[diff_21_15] = none_21_15

df_acidente_transito_16_ = df_acidente_transito_16.reindex(columns=df_acidente_transito_16.columns.tolist() + diff_21_16)   
df_acidente_transito_17_ = df_acidente_transito_17.reindex(columns=df_acidente_transito_17.columns.tolist() + diff_21_17)   
df_acidente_transito_18_ = df_acidente_transito_18.reindex(columns=df_acidente_transito_18.columns.tolist() + diff_21_18)   
df_acidente_transito_19_ = df_acidente_transito_19.reindex(columns=df_acidente_transito_19.columns.tolist() + diff_21_19)
df_acidente_transito_20_ = df_acidente_transito_20.reindex(columns=df_acidente_transito_20.columns.tolist() + diff_21_20)

# %%
print(df_acidente_transito_15_.columns,'\n')
print(df_acidente_transito_16_.columns,'\n')
print(df_acidente_transito_17_.columns,'\n')
print(df_acidente_transito_18_.columns,'\n')
print(df_acidente_transito_19_.columns,'\n')
print(df_acidente_transito_20_.columns,'\n')
print(df_acidente_transito_21_.columns,'\n')
# Out:
# Index(['TIPO', 'SITUACAO', 'DATA', 'HORA', 'BAIRRO', 'ENDERECO', 'NUMERO', 'COMPLEMENTO', 'NATUREZA', 'DESCRICAO', 'AUTO', 'MOTO', 'CICLOM', 'CICLISTA', 'PEDESTRE', 'ONIBUS', 'CAMINHAO', 'VIATURA', 'OUTROS', 'VITIMAS', 'NATUREZA_ACIDENTE', 'DETALHE_ENDERECO_ACIDENTE', 'BAIRRO_CRUZAMENTO', 'NUM_SEMAFORO', 'SENTIDO_VIA', 'VITIMASFATAIS', 'ACIDENTE_VERIFICADO', 'TEMPO_CLIMA', 'SITUACAO_SEMAFORO', 'SINALIZACAO', 'CONDICAO_VIA', 'CONSERVACAO_VIA', 'PONTO_CONTROLE', 'SITUACAO_PLACA', 'VELOCIDADE_MAX_VIA', 'MAO_DIRECAO', 'DIVISAO_VIA1', 'DIVISAO_VIA2', 'DIVISAO_VIA3', 'ENDERECO_CRUZAMENTO', 'NUMERO_CRUZAMENTO', 'REFERENCIA_CRUZAMENTO'], dtype='object')
#
# ...

# %%
print(df_acidente_transito_15_[df_acidente_transito_21_.columns].columns,'\n')
print(df_acidente_transito_16_[df_acidente_transito_21_.columns].columns,'\n')
print(df_acidente_transito_17_[df_acidente_transito_21_.columns].columns,'\n')
print(df_acidente_transito_18_[df_acidente_transito_21_.columns].columns,'\n')
print(df_acidente_transito_19_[df_acidente_transito_21_.columns].columns,'\n')
print(df_acidente_transito_20_[df_acidente_transito_21_.columns].columns,'\n')
print(df_acidente_transito_21_[df_acidente_transito_21_.columns].columns,'\n')

print(len(df_acidente_transito_15_.columns),len(df_acidente_transito_16_.columns),len(df_acidente_transito_17_.columns),len(df_acidente_transito_18_.columns),len(df_acidente_transito_19_.columns),len(df_acidente_transito_20_.columns),len(df_acidente_transito_21_.columns),'\n')
# Out:
# Index(['DATA', 'HORA', 'NATUREZA_ACIDENTE', 'SITUACAO', 'BAIRRO', 'ENDERECO', 'NUMERO', 'DETALHE_ENDERECO_ACIDENTE', 'COMPLEMENTO', 'BAIRRO_CRUZAMENTO', 'NUM_SEMAFORO', 'SENTIDO_VIA', 'TIPO', 'DESCRICAO', 'AUTO', 'MOTO', 'CICLOM', 'CICLISTA', 'PEDESTRE', 'ONIBUS', 'CAMINHAO', 'VIATURA', 'OUTROS', 'VITIMAS', 'VITIMASFATAIS', 'ACIDENTE_VERIFICADO', 'TEMPO_CLIMA', 'SITUACAO_SEMAFORO', 'SINALIZACAO', 'CONDICAO_VIA', 'CONSERVACAO_VIA', 'PONTO_CONTROLE', 'SITUACAO_PLACA', 'VELOCIDADE_MAX_VIA', 'MAO_DIRECAO', 'DIVISAO_VIA1', 'DIVISAO_VIA2', 'DIVISAO_VIA3', 'NATUREZA', 'ENDERECO_CRUZAMENTO', 'NUMERO_CRUZAMENTO', 'REFERENCIA_CRUZAMENTO'], dtype='object')
#
# ...

# %% [markdown]
# Visualizando os dados dos Datasets

# %%
df_acidente_transito_15_.head(2)
# Out:
#          TIPO    SITUACAO        DATA          HORA        BAIRRO      ENDERECO  NUMERO                       COMPLEMENTO NATUREZA            DESCRICAO  AUTO  MOTO  CICLOM  CICLISTA  PEDESTRE  ONIBUS  CAMINHAO  VIATURA  OUTROS  VITIMAS  NATUREZA_ACIDENTE  DETALHE_ENDERECO_ACIDENTE  BAIRRO_CRUZAMENTO  NUM_SEMAFORO  SENTIDO_VIA  VITIMASFATAIS  ACIDENTE_VERIFICADO  TEMPO_CLIMA  SITUACAO_SEMAFORO  SINALIZACAO  CONDICAO_VIA  CONSERVACAO_VIA  PONTO_CONTROLE  SITUACAO_PLACA  VELOCIDADE_MAX_VIA  MAO_DIRECAO  DIVISAO_VIA1  DIVISAO_VIA2  DIVISAO_VIA3  ENDERECO_CRUZAMENTO  NUMERO_CRUZAMENTO  REFERENCIA_CRUZAMENTO
# ...

# %%
df_acidente_transito_16_.head(2)
# Out:
#          DATA      HORA NATUREZA_ACIDENTE    SITUACAO      BAIRRO                                    ENDERECO NUMERO DETALHE_ENDERECO_ACIDENTE                                      COMPLEMENTO                         ENDERECO_CRUZAMENTO NUMERO_CRUZAMENTO                            REFERENCIA_CRUZAMENTO BAIRRO_CRUZAMENTO     TIPO                                   DESCRICAO  AUTO  MOTO  CICLOM  CICLISTA  PEDESTRE  ONIBUS  CAMINHAO  VIATURA  OUTROS  VITIMAS  VITIMASFATAIS  NUM_SEMAFORO  SENTIDO_VIA  ACIDENTE_VERIFICADO  TEMPO_CLIMA  SITUACAO_SEMAFORO  SINALIZACAO  CONDICAO_VIA  CONSERVACAO_VIA  PONTO_CONTROLE  SITUACAO_PLACA  VELOCIDADE_MAX_VIA  MAO_DIRECAO  DIVISAO_VIA1  DIVISAO_VIA2  DIVISAO_VIA3  NATUREZA
# ...

# %%
df_acidente_transito_17_.head(2)
# Out:
#          DATA      HORA NATUREZA_ACIDENTE    SITUACAO       BAIRRO            ENDERECO NUMERO DETALHE_ENDERECO_ACIDENTE                      COMPLEMENTO ENDERECO_CRUZAMENTO NUMERO_CRUZAMENTO            REFERENCIA_CRUZAMENTO BAIRRO_CRUZAMENTO         TIPO  AUTO  MOTO  CICLOM  CICLISTA  PEDESTRE  ONIBUS  CAMINHAO  VIATURA  OUTROS  VITIMAS  VITIMASFATAIS  NUM_SEMAFORO  SENTIDO_VIA  DESCRICAO  ACIDENTE_VERIFICADO  TEMPO_CLIMA  SITUACAO_SEMAFORO  SINALIZACAO  CONDICAO_VIA  CONSERVACAO_VIA  PONTO_CONTROLE  SITUACAO_PLACA  VELOCIDADE_MAX_VIA  MAO_DIRECAO  DIVISAO_VIA1  DIVISAO_VIA2  DIVISAO_VIA3  NATUREZA
# ...

# %%
df_acidente_transito_18_.head(2)
# Out:
#          DATA      HORA NATUREZA_ACIDENTE    SITUACAO    BAIRRO                     ENDERECO NUMERO DETALHE_ENDERECO_ACIDENTE                                        COMPLEMENTO          ENDERECO_CRUZAMENTO NUMERO_CRUZAMENTO                              REFERENCIA_CRUZAMENTO BAIRRO_CRUZAMENTO  NUM_SEMAFORO SENTIDO_VIA           TIPO                    DESCRICAO  AUTO  MOTO  CICLOM  CICLISTA  PEDESTRE  ONIBUS  CAMINHAO  VIATURA  OUTROS  VITIMAS  VITIMASFATAIS ACIDENTE_VERIFICADO TEMPO_CLIMA SITUACAO_SEMAFORO SINALIZACAO CONDICAO_VIA CONSERVACAO_VIA PONTO_CONTROLE SITUACAO_PLACA VELOCIDADE_MAX_VIA MAO_DIRECAO DIVISAO_VIA1 DIVISAO_VIA2 DIVISAO_VIA3  NATUREZA
# ...

# %%
df_acidente_transito_19_.head(2)
# Out:
#          DATA      HORA NATUREZA_ACIDENTE    SITUACAO      BAIRRO                    ENDERECO NUMERO    DETALHE_ENDERECO_ACIDENTE             COMPLEMENTO         ENDERECO_CRUZAMENTO NUMERO_CRUZAMENTO   REFERENCIA_CRUZAMENTO BAIRRO_CRUZAMENTO  NUM_SEMAFORO SENTIDO_VIA                      TIPO                                          DESCRICAO  AUTO  MOTO  CICLOM  CICLISTA  PEDESTRE  ONIBUS  CAMINHAO  VIATURA  OUTROS  VITIMAS  VITIMASFATAIS ACIDENTE_VERIFICADO TEMPO_CLIMA SITUACAO_SEMAFORO      SINALIZACAO CONDICAO_VIA  CONSERVACAO_VIA     PONTO_CONTROLE SITUACAO_PLACA VELOCIDADE_MAX_VIA MAO_DIRECAO      DIVISAO_VIA1 DIVISAO_VIA2 DIVISAO_VIA3  NATUREZA
# ...

# %%
df_acidente_transito_20_.head(2)
# Out:
#          DATA      HORA NATUREZA_ACIDENTE    SITUACAO     BAIRRO           ENDERECO NUMERO DETALHE_ENDERECO_ACIDENTE                   COMPLEMENTO BAIRRO_CRUZAMENTO  NUM_SEMAFORO SENTIDO_VIA                       TIPO                     DESCRICAO  AUTO  MOTO  CICLOM  CICLISTA  PEDESTRE  ONIBUS  CAMINHAO  VIATURA  OUTROS  VITIMAS  VITIMASFATAIS ACIDENTE_VERIFICADO TEMPO_CLIMA SITUACAO_SEMAFORO      SINALIZACAO CONDICAO_VIA  CONSERVACAO_VIA     PONTO_CONTROLE SITUACAO_PLACA VELOCIDADE_MAX_VIA MAO_DIRECAO      DIVISAO_VIA1 DIVISAO_VIA2 DIVISAO_VIA3  NATUREZA  ENDERECO_CRUZAMENTO  NUMERO_CRUZAMENTO  REFERENCIA_CRUZAMENTO
# ...

# %%
df_acidente_transito_21_.head(2)
# Out:
#          DATA      HORA NATUREZA_ACIDENTE    SITUACAO    BAIRRO     ENDERECO NUMERO DETALHE_ENDERECO_ACIDENTE                  COMPLEMENTO BAIRRO_CRUZAMENTO  NUM_SEMAFORO SENTIDO_VIA              TIPO             DESCRICAO  AUTO  MOTO  CICLOM  CICLISTA  PEDESTRE  ONIBUS  CAMINHAO  VIATURA  OUTROS  VITIMAS  VITIMASFATAIS ACIDENTE_VERIFICADO TEMPO_CLIMA SITUACAO_SEMAFORO      SINALIZACAO CONDICAO_VIA  CONSERVACAO_VIA PONTO_CONTROLE SITUACAO_PLACA VELOCIDADE_MAX_VIA MAO_DIRECAO    DIVISAO_VIA1      DIVISAO_VIA2 DIVISAO_VIA3  NATUREZA  ENDERECO_CRUZAMENTO  NUMERO_CRUZAMENTO  REFERENCIA_CRUZAMENTO
# ...

# %%
df_acidente_transito_15_2 = df_acidente_transito_15_.rename(columns={'TIPO':'NATUREZA_ACIDENTE','NATUREZA':'TIPO','NATUREZA_ACIDENTE':'NATUREZA'})

# %%
df_acidente_transito_15_2.head(2)
# Out:
#   NATUREZA_ACIDENTE    SITUACAO        DATA          HORA        BAIRRO      ENDERECO  NUMERO                       COMPLEMENTO     TIPO            DESCRICAO  AUTO  MOTO  CICLOM  CICLISTA  PEDESTRE  ONIBUS  CAMINHAO  VIATURA  OUTROS  VITIMAS  NATUREZA  DETALHE_ENDERECO_ACIDENTE  BAIRRO_CRUZAMENTO  NUM_SEMAFORO  SENTIDO_VIA  VITIMASFATAIS  ACIDENTE_VERIFICADO  TEMPO_CLIMA  SITUACAO_SEMAFORO  SINALIZACAO  CONDICAO_VIA  CONSERVACAO_VIA  PONTO_CONTROLE  SITUACAO_PLACA  VELOCIDADE_MAX_VIA  MAO_DIRECAO  DIVISAO_VIA1  DIVISAO_VIA2  DIVISAO_VIA3  ENDERECO_CRUZAMENTO  NUMERO_CRUZAMENTO  REFERENCIA_CRUZAMENTO
# ...

# %% [markdown]
# Unificando os Layouts

# %%
df_union = [df_acidente_transito_15_2[df_acidente_transito_21_.columns],
            df_acidente_transito_16_[df_acidente_transito_21_.columns],
            df_acidente_transito_17_[df_acidente_transito_21_.columns],
            df_acidente_transito_18_[df_acidente_transito_21_.columns],
            df_acidente_transito_19_[df_acidente_transito_21_.columns],
            df_acidente_transito_20_[df_acidente_transito_21_.columns],
            df_acidente_transito_21_[df_acidente_transito_21_.columns]]

df_final = pd.concat(df_union)

# %%
df_final['DETALHE_ENDERECO_ACIDENTE'].unique()
# Out:
# array([nan, 'AV PROFESSOR JOSE DOS ANJOS', 'AV PROFESSOR ARTUR DE SA',
#        ..., 'RUA DO ARAGAO', 'RUA PADRE CAPISTRANO', 'RUA FREI AMADOR'],
#       dtype=object)

# %% [markdown]
# Salvando tabela ...

# %%
df_final.to_csv(r'acidentes_transito_2015_2021.csv', sep=';' , index = False )

# %% [markdown]
# # Infrações de Transito

# %%
df_relatorio_multas_2015 = pd.read_csv("relatorio_multas_2015.csv", delimiter=';',low_memory=False)
df_relatorio_multas_2015.columns = map(str.upper, df_relatorio_multas_2015.columns)

df_relatorio_multas_2016 = pd.read_csv("relatorio_multas_2016.csv", delimiter=';',low_memory=False)
df_relatorio_multas_2016.columns = map(str.upper, df_relatorio_multas_2016.columns)

df_relatorio_multas_2017 = pd.read_csv("relatorio_multas_2017.csv", delimiter=';',low_memory=False)
df_relatorio_multas_2017.columns = map(str.upper, df_relatorio_multas_2017.columns)

df_relatorio_multas_2018 = pd.read_csv("relatorio_multas_2018.csv", delimiter=';',low_memory=False)
df_relatorio_multas_2018.columns = map(str.upper, df_relatorio_multas_2018.columns)

df_relatorio_multas_2019 = pd.read_csv("relatorio_multas_2019.csv", delimiter=';',low_memory=False)
df_relatorio_multas_2019.columns = map(str.upper, df_relatorio_multas_2019.columns)

df_relatorio_multas_2020 = pd.read_csv("relatorio_multas_2020.csv", delimiter=';',low_memory=False)
df_relatorio_multas_2020.columns = map(str.upper, df_relatorio_multas_2020.columns)

df_relatorio_multas_2021 = pd.read_csv("relatorio_multas_2021.csv", delimiter=';',low_memory=False)
df_relatorio_multas_2021.columns = map(str.upper, df_relatorio_multas_2021.columns)

print("2015 - " , df_relatorio_multas_2015.columns,'\n')
print("2016 - " , df_relatorio_multas_2016.columns,'\n')
print("2017 - " , df_relatorio_multas_2017.columns,'\n')
print("2018 - " , df_relatorio_multas_2018.columns,'\n')
print("2019 - " , df_relatorio_multas_2019.columns,'\n')
print("2020 - " , df_relatorio_multas_2020.columns,'\n')
print("2021 - " , df_relatorio_multas_2021.columns,'\n')
# Out:
# 2015 -  Index(['DATAINFRACAO', 'HORAINFRACAO', 'DATAIMPLANTACAO', 'AGENTEEQUIPAMENTO', 'INFRACAO', 'DESCRICAOINFRACAO', 'AMPAROLEGAL', 'LOCALCOMETIMENTO'], dtype='object')
#
# 2016 -  Index(['DATAINFRACAO', 'HORAINFRACAO', 'DATAIMPLANTACAO', 'AGENTEEQUIPAMENTO', 'INFRACAO', 'DESCRICAOINFRACAO', 'AMPAROLEGAL', 'LOCALCOMETIMENTO'], dtype='object')
#
# 2017 -  Index(['DATAINFRACAO', 'HORAINFRACAO', 'DATAIMPLANTACAO', 'AGENTEEQUIPAMENTO', 'INFRACAO', 'DESCRICAOINFRACAO', 'AMPAROLEGAL', 'LOCALCOMETIMENTO'], dtype='object')
#
# 2018 -  Index(['DATAINFRACAO', 'HORAINFRACAO', 'DATAIMPLANTACAO', 'AGENTEEQUIPAMENTO', 'INFRACAO', 'DESCRICAOINFRACAO', 'AMPAROLEGAL', 'LOCALCOMETIMENTO'], dtype='object')
#
# 2019 -  Index(['DATAINFRACAO', 'HORAINFRACAO', 'DATAIMPLANTACAO', 'AGENTEEQUIPAMENTO', 'INFRACAO', 'DESCRICAOINFRACAO', 'AMPAROLEGAL', 'LOCALCOMETIMENTO'], dtype='object')
#
# ...

# %% [markdown]
# Visualizando conteúdo dos dados

# %%
df_relatorio_multas_2015.head(2)
# Out:
#               DATAINFRACAO HORAINFRACAO          DATAIMPLANTACAO                 AGENTEEQUIPAMENTO  INFRACAO                                  DESCRICAOINFRACAO          AMPAROLEGAL                      LOCALCOMETIMENTO
# 0  2015/10/26 00:00:00.000     08:42:00  2015/11/03 00:00:00.000  Código 6 - AUTOS NO TALÃO MANUAL      5541  Estacionar o veículo em desacordo com as condi...  Art. 181, Inc. XVII  AV PORTUGAL EM FRENTE AO IMOVEL N 89
# 1  2015/10/26 00:00:00.000     08:45:00  2015/11/03 00:00:00.000  Código 6 - AUTOS NO TALÃO MANUAL      5541  Estacionar o veículo em desacordo com as condi...  Art. 181, Inc. XVII  AV PORTUGAL EM FRENTE AO IMOVEL N 89

# %%
df_relatorio_multas_2016.head(2)
# Out:
#   DATAINFRACAO HORAINFRACAO DATAIMPLANTACAO                 AGENTEEQUIPAMENTO  INFRACAO                                  DESCRICAOINFRACAO AMPAROLEGAL                            LOCALCOMETIMENTO
# 0   2016-01-01     01:55:00      2016-01-04  Código 6 - AUTOS NO TALÃO MANUAL    6050.0              Avançar o sinal vermelho do semáforo.    Art. 208  AV CONS AGUIAR EM FRENTE AO SEMAFORO N 140
# 1   2016-01-01     02:20:00      2016-01-04  Código 6 - AUTOS NO TALÃO MANUAL    5835.0  Desobedecer às ordens emanadas da autoridade c...    Art. 195  AV CONS AGUIAR EM FRENTE AO SEMAFORO N 140

# %%
df_relatorio_multas_2017.head(2)
# Out:
#   DATAINFRACAO HORAINFRACAO DATAIMPLANTACAO                     AGENTEEQUIPAMENTO  INFRACAO                                  DESCRICAOINFRACAO          AMPAROLEGAL                                   LOCALCOMETIMENTO
# 0   2017-01-01     20:12:24      2017-01-05  Código 8 - AUTOS NO TALÃO ELETRÔNICO      5452                   Estacionar o veículo no passeio.  Art. 181, Inc. VIII      AVENIDA CONSELHEIRO AGUIAR, AO LADO  BOMPRECO
# 1   2017-01-01     07:38:21      2017-01-25         Código 3 - LOMBADA ELETRÔNICA      7455  Transitar em velocidade superior à máxima perm...     Art. 218, Inc. I  AV. MARECHAL MASCARENHAS DE MORAES - SEMAFORO,...

# %%
df_relatorio_multas_2018.head(2)
# Out:
#   DATAINFRACAO HORAINFRACAO DATAIMPLANTACAO                     AGENTEEQUIPAMENTO  INFRACAO                                  DESCRICAOINFRACAO           AMPAROLEGAL                                   LOCALCOMETIMENTO
# 0   2018-01-01     00:02:07      2018-01-04  Código 8 - AUTOS NO TALÃO ELETRÔNICO      5550  Estacionar o veículo em locais e horários proi...  Art. 181, Inc. XVIII  RUA CARLOS PEREIRA FALCAO .SENTIDO UNICO ., AO...
# 1   2018-01-01     00:03:51      2018-01-04  Código 8 - AUTOS NO TALÃO ELETRÔNICO      5550  Estacionar o veículo em locais e horários proi...  Art. 181, Inc. XVIII  RUA CARLOS PEREIRA FALCAO .SENTIDO UNICO ., AO...

# %%
df_relatorio_multas_2019.head(2)
# Out:
#   DATAINFRACAO HORAINFRACAO DATAIMPLANTACAO                     AGENTEEQUIPAMENTO INFRACAO                 DESCRICAOINFRACAO          AMPAROLEGAL                                LOCALCOMETIMENTO
# 0   2019-01-01     00:01:00      2019-01-08  Código 8 - AUTOS NO TALÃO ELETRÔNICO     5452  Estacionar o veículo no passeio.  Art. 181, Inc. VIII  RUA TENENTE JOAO CICERO, LADO OPOSTO AO N. 170
# 1   2019-01-01     00:02:00      2019-01-08  Código 8 - AUTOS NO TALÃO ELETRÔNICO     5452  Estacionar o veículo no passeio.  Art. 181, Inc. VIII  RUA TENENTE JOAO CICERO, LADO OPOSTO AO N. 170

# %%
df_relatorio_multas_2020.head(2)
# Out:
#   DATAINFRACAO HORAINFRACAO DATAIMPLANTACAO                     AGENTEEQUIPAMENTO  INFRACAO                                  DESCRICAOINFRACAO        AMPAROLEGAL                          LOCALCOMETIMENTO
# 0   2020-01-01     00:01:00      2020-01-13  Código 8 - AUTOS NO TALÃO ELETRÔNICO      7366  Dirigir o veículo utilizando-se de telefone ce...  Art. 252, Inc. VI  RUA DOS NAVEGANTES, EM FRENTE AO N. 1455
# 1   2020-01-01     00:01:00      2020-01-13  Código 8 - AUTOS NO TALÃO ELETRÔNICO      5487  Estacionar o veículo ao lado de outro veículo ...  Art. 181, Inc. XI  RUA DOS NAVEGANTES, EM FRENTE AO N. 4862

# %%
df_relatorio_multas_2021.head(2)
# Out:
#   DATAINFRACAO HORAINFRACAO DATAIMPLANTACAO              AGENTEEQUIPAMENTO  INFRACAO                                  DESCRICAOINFRACAO       AMPAROLEGAL                                   LOCALCOMETIMENTO
# 0   2021-01-01     06:04:31      2021-01-20  Código 3 - LOMBADA ELETRÔNICA      7455  Transitar em velocidade superior à máxima perm...  Art. 218, Inc. I  AV. GOV. AGAMENON MAGALHAES, SEMAFORO 069, Sen...
# 1   2021-01-01     06:04:59      2021-01-20  Código 3 - LOMBADA ELETRÔNICA      7455  Transitar em velocidade superior à máxima perm...  Art. 218, Inc. I  AV. NORTE MIGUEL ARRAES DE ALENCAR, SEMAFORO 4...

# %% [markdown]
# Como os dados estão com os layouts iguais, serão unificados diretamente

# %%
df_union = [df_relatorio_multas_2015[df_relatorio_multas_2021.columns],
            df_relatorio_multas_2016[df_relatorio_multas_2021.columns],
            df_relatorio_multas_2017[df_relatorio_multas_2021.columns],
            df_relatorio_multas_2018[df_relatorio_multas_2021.columns],
            df_relatorio_multas_2019[df_relatorio_multas_2021.columns],
            df_relatorio_multas_2020[df_relatorio_multas_2021.columns],
            df_relatorio_multas_2021[df_relatorio_multas_2021.columns]]

df_final = pd.concat(df_union)

# %%
df_final.head(5)
# Out:
#               DATAINFRACAO HORAINFRACAO          DATAIMPLANTACAO                 AGENTEEQUIPAMENTO INFRACAO                                  DESCRICAOINFRACAO           AMPAROLEGAL                                   LOCALCOMETIMENTO
# 0  2015/10/26 00:00:00.000     08:42:00  2015/11/03 00:00:00.000  Código 6 - AUTOS NO TALÃO MANUAL     5541  Estacionar o veículo em desacordo com as condi...   Art. 181, Inc. XVII               AV PORTUGAL EM FRENTE AO IMOVEL N 89
# 1  2015/10/26 00:00:00.000     08:45:00  2015/11/03 00:00:00.000  Código 6 - AUTOS NO TALÃO MANUAL     5541  Estacionar o veículo em desacordo com as condi...   Art. 181, Inc. XVII               AV PORTUGAL EM FRENTE AO IMOVEL N 89
# 2  2015/10/26 00:00:00.000     08:48:00  2015/11/03 00:00:00.000  Código 6 - AUTOS NO TALÃO MANUAL     5525      Estacionar o veículo na contramão de direção.     Art. 181, Inc. XV              AV PORTUGAL EM FRENTE AO IMOVEL N 101
# ...

# %%
df_final['LOCALCOMETIMENTO'].unique()
# Out:
# array(['AV PORTUGAL EM FRENTE AO IMOVEL N 89',
#        'AV PORTUGAL EM FRENTE AO IMOVEL N 101',
#        'RUA PACIFICO DOS SANTOS EM FRENTE AO IMOVEL N 124', ...,
#        'AVENIDA CRUZ CABUGA, EM FRENTE AO N. 304 SENTIDO OLINDA',
#        'AVENIDA RUI BARBOSA, ESQUINA RUA DEP. PEDRO PIRESFERREIRA',
#        'RUA JOSE DE ALENCAR, LADO OPOSTO A UNIMED 3'], dtype=object)

# %% [markdown]
# Salvando tabela ...

# %%
df_final.to_csv(r'relatorio_multas_2015_2021.csv', sep=';' , index = False )

# %% [markdown]
# # Velocidades de Vias - Velocidades Media a cada 15 minutos

# %%
df_2016 = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_2016.csv", delimiter=';',low_memory=False)
df_2016.columns = map(str.upper, df_2016.columns)

df_2017 = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_2017.csv", delimiter=';',low_memory=False)
df_2017.columns = map(str.upper, df_2017.columns)

df_2018 = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_2018.csv", delimiter=';',low_memory=False)
df_2018.columns = map(str.upper, df_2018.columns)

print(df_2016.columns,'\n')
print(df_2017.columns,'\n')
print(df_2018.columns,'\n')
# Out:
# Index(['MES', 'EQUIPAMENTO', 'FAIXA', 'DATA', 'HORA', 'MINUTOS_INTERVALO', 'QTD_0A10KM', 'QTD_11A20KM', 'QTD_21A30KM', 'QTD_31A40KM', 'QTD_41A50KM', 'QTD_51A60KM', 'QTD_61A70KM', 'QTD_71A80KM', 'QTD_81A90KM', 'QTD_91A100KM', 'QTD_ACIMADE100KM'], dtype='object')
#
# Index(['MES', 'EQUIPAMENTO', 'FAIXA', 'DATA', 'HORA', 'MINUTOS_INTERVALO', 'QTD_0A10KM', 'QTD_11A20KM', 'QTD_21A30KM', 'QTD_31A40KM', 'QTD_41A50KM', 'QTD_51A60KM', 'QTD_61A70KM', 'QTD_71A80KM', 'QTD_81A90KM', 'QTD_91A100KM', 'QTD_ACIMADE100KM'], dtype='object')
#
# Index(['MES', 'EQUIPAMENTO', 'FAIXA', 'DATA', 'HORA', 'MINUTOS_INTERVALO', 'QTD_0A10KM', 'QTD_11A20KM', 'QTD_21A30KM', 'QTD_31A40KM', 'QTD_41A50KM', 'QTD_51A60KM', 'QTD_61A70KM', 'QTD_71A80KM', 'QTD_81A90KM', 'QTD_91A100KM', 'QTD_ACIMADE100KM'], dtype='object')

# %% [markdown]
# Adicionando coluna de controle de ANO do arquivo utilizado,assim como realizando uma redefinição dos tipos das colunas, para ser mais facil unifica-lás depois

# %%
df_2016.insert(0,"ANO",2016,True)
df_2017.insert(0,"ANO",2017,True)
df_2018.insert(0,"ANO",2018,True)

df_2016 = df_2016.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_2017 = df_2017.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_2018 = df_2018.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

# %%
df_2018.head(5)
# Out:
#     ANO  MES EQUIPAMENTO FAIXA        DATA HORA MINUTOS_INTERVALO QTD_0A10KM QTD_11A20KM QTD_21A30KM QTD_31A40KM QTD_41A50KM QTD_51A60KM QTD_61A70KM QTD_71A80KM QTD_81A90KM QTD_91A100KM QTD_ACIMADE100KM
# 0  2018    1    FS002REC     1  2018-01-01    0              0-15          2           5           2           1           0           0           0           0           0            0                0
# 1  2018    1    FS002REC     1  2018-01-01    0             16-30          1          10           3           1           0           0           0           0           0            0                0
# 2  2018    1    FS002REC     1  2018-01-01    0             31-45          0          12           5           2           0           0           0           0           0            0                0
# ...

# %% [markdown]
# Leitura das tabelas (*separadas em meses*) dos seguintes anos (2019, 2020 e inicio de  2021)

# %% [markdown]
# Como ocorreu alguns ***erros*** nas tabelas, foi necessário definir um limite de leitura para algumas delas, utilizando o parametro ***nrows***

# %%
df_201901_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201901_f.csv", delimiter=';',low_memory=False)
df_201901_f.columns = map(str.upper, df_201901_f.columns)

df_201902_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201902_f.csv", delimiter=';',low_memory=False)
df_201902_f.columns = map(str.upper, df_201902_f.columns)

df_201903_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201903_f.csv", delimiter=';',nrows=100949)
df_201903_f.columns = map(str.upper, df_201903_f.columns)

df_201904_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201904_f.csv", delimiter=';',low_memory=False)
df_201904_f.columns = map(str.upper, df_201904_f.columns)

df_201905_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201905_f.csv", delimiter=';',low_memory=False)
df_201905_f.columns = map(str.upper, df_201905_f.columns)

df_201906_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201906_f.csv", delimiter=';',nrows=99067,low_memory=False)
df_201906_f.columns = map(str.upper, df_201906_f.columns)

df_201907_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201907_f.csv", delimiter=';',nrows=98926,low_memory=False)
df_201907_f.columns = map(str.upper, df_201907_f.columns)

df_201908_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201908_f.csv", delimiter=';',nrows=98613,low_memory=False)
df_201908_f.columns = map(str.upper, df_201908_f.columns)

df_201909_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201909_f.csv", delimiter=';',nrows=98622,low_memory=False)
df_201909_f.columns = map(str.upper, df_201909_f.columns)

df_201910_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201910_f.csv", delimiter=';',nrows=32660,low_memory=False)
df_201910_f.columns = map(str.upper, df_201910_f.columns)

df_201911_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201911_f.csv", delimiter=';',low_memory=False)
df_201911_f.columns = map(str.upper, df_201911_f.columns)

df_201912_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201912_f.csv", delimiter=';',low_memory=False)
df_201912_f.columns = map(str.upper, df_201912_f.columns)

df_201901_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201901_l.csv", delimiter=';',nrows=88677,low_memory=False)
df_201901_l.columns = map(str.upper, df_201901_l.columns)

df_201902_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201902_l.csv", delimiter=';',nrows=88406,low_memory=False)
df_201902_l.columns = map(str.upper, df_201902_l.columns)

df_201903_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201903_l.csv", delimiter=';',nrows=88524,low_memory=False)
df_201903_l.columns = map(str.upper, df_201903_l.columns)

df_201904_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201904_l.csv", delimiter=';',nrows=88524,low_memory=False)
df_201904_l.columns = map(str.upper, df_201904_l.columns)

df_201905_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201905_l.csv", delimiter=';',nrows=88411,low_memory=False)
df_201905_l.columns = map(str.upper, df_201905_l.columns)

df_201906_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201906_l.csv", delimiter=';',low_memory=False)
df_201906_l.columns = map(str.upper, df_201906_l.columns)

df_201907_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201907_l.csv", delimiter=';',low_memory=False)
df_201907_l.columns = map(str.upper, df_201907_l.columns)

df_201908_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201908_l.csv", delimiter=';',low_memory=False)
df_201908_l.columns = map(str.upper, df_201908_l.columns)

df_201909_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201909_l.csv", delimiter=';',low_memory=False)
df_201909_l.columns = map(str.upper, df_201909_l.columns)

df_201910_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201910_l.csv", delimiter=';',low_memory=False)
df_201910_l.columns = map(str.upper, df_201910_l.columns)

df_201911_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201911_l.csv", delimiter=';',low_memory=False)
df_201911_l.columns = map(str.upper, df_201911_l.columns)

df_201912_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201912_l.csv", delimiter=';',low_memory=False)
df_201912_l.columns = map(str.upper, df_201912_l.columns)

df_202001_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202001_f.csv", delimiter=';',nrows=99230,low_memory=False)
df_202001_f.columns = map(str.upper, df_202001_f.columns)

df_202002_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202002_f.csv", delimiter=';',nrows=98961,low_memory=False)
df_202002_f.columns = map(str.upper, df_202002_f.columns)

df_202003_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202003_f.csv", delimiter=';',nrows=99617,low_memory=False)
df_202003_f.columns = map(str.upper, df_202003_f.columns)

df_202004_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202004_f.csv", delimiter=';',low_memory=False)
df_202004_f.columns = map(str.upper, df_202004_f.columns)

df_202005_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202005_f.csv", delimiter=';',low_memory=False)
df_202005_f.columns = map(str.upper, df_202005_f.columns)

df_202006_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202006_f.csv", delimiter=';',low_memory=False)
df_202006_f.columns = map(str.upper, df_202006_f.columns)

df_202007_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202007_f.csv", delimiter=';',low_memory=False)
df_202007_f.columns = map(str.upper, df_202007_f.columns)

df_202008_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202008_f.csv", delimiter=';',nrows=50360,low_memory=False)
df_202008_f.columns = map(str.upper, df_202008_f.columns)

df_202009_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202009_f.csv", delimiter=';',low_memory=False)
df_202009_f.columns = map(str.upper, df_202009_f.columns)

df_202010_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202010_f.csv", delimiter=';',low_memory=False)
df_202010_f.columns = map(str.upper, df_202010_f.columns)

df_202011_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202011_f.csv", delimiter=';',low_memory=False)
df_202011_f.columns = map(str.upper, df_202011_f.columns)

df_202012_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202012_f.csv", delimiter=';',low_memory=False)
df_202012_f.columns = map(str.upper, df_202012_f.columns)

df_202001_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202001_l.csv", delimiter=';',low_memory=False)
df_202001_l.columns = map(str.upper, df_202001_l.columns)

df_202002_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202002_l.csv", delimiter=';',low_memory=False)
df_202002_l.columns = map(str.upper, df_202002_l.columns)

df_202003_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202003_l.csv", delimiter=';',low_memory=False)
df_202003_l.columns = map(str.upper, df_202003_l.columns)

df_202004_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202004_l.csv", delimiter=';',low_memory=False)
df_202004_l.columns = map(str.upper, df_202004_l.columns)

df_202005_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202005_l.csv", delimiter=';',low_memory=False)
df_202005_l.columns = map(str.upper, df_202005_l.columns)

df_202006_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202006_l.csv", delimiter=';',low_memory=False)
df_202006_l.columns = map(str.upper, df_202006_l.columns)

df_202007_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202007_l.csv", delimiter=';',nrows=102396,low_memory=False)
df_202007_l.columns = map(str.upper, df_202007_l.columns)

df_202008_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202008_l.csv", delimiter=';',nrows=87760,low_memory=False)
df_202008_l.columns = map(str.upper, df_202008_l.columns)

df_202009_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202009_l.csv", delimiter=';',low_memory=False)
df_202009_l.columns = map(str.upper, df_202009_l.columns)

df_202010_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202010_l.csv", delimiter=';',low_memory=False)
df_202010_l.columns = map(str.upper, df_202010_l.columns)

df_202011_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202011_l.csv", delimiter=';',low_memory=False)
df_202011_l.columns = map(str.upper, df_202011_l.columns)

df_202012_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202012_l.csv", delimiter=';',nrows=87543,low_memory=False)
df_202012_l.columns = map(str.upper, df_202012_l.columns)

df_202101_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202101_f.csv", delimiter=';',low_memory=False)
df_202101_f.columns = map(str.upper, df_202101_f.columns)

df_202102_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202102_f.csv", delimiter=';',low_memory=False)
df_202102_f.columns = map(str.upper, df_202102_f.columns)

df_202103_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202103_f.csv", delimiter=';',low_memory=False)
df_202103_f.columns = map(str.upper, df_202103_f.columns)

df_202104_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202104_f.csv", delimiter=';',low_memory=False)
df_202104_f.columns = map(str.upper, df_202104_f.columns)

df_202105_f = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202105_f.csv", delimiter=';',low_memory=False)
df_202105_f.columns = map(str.upper, df_202105_f.columns)

df_202102_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202102_l.csv", delimiter=';',low_memory=False)
df_202102_l.columns = map(str.upper, df_202102_l.columns)

df_202104_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202104_l.csv", delimiter=';',low_memory=False)
df_202104_l.columns = map(str.upper, df_202104_l.columns)

df_202105_l = pd.read_csv("/content/velocidades_vias_velocidade_media_15min_202105_l.csv", delimiter=';',low_memory=False)
df_202105_l.columns = map(str.upper, df_202105_l.columns)

# %% [markdown]
# Verificando Layout das tabelas

# %%
print('df_201901_f - ',df_201901_f.columns ,'\n')
print('df_201902_f - ',df_201902_f.columns ,'\n')
print('df_201903_f - ',df_201903_f.columns ,'\n')
print('df_201904_f - ',df_201904_f.columns ,'\n')
print('df_201905_f - ',df_201905_f.columns ,'\n')
print('df_201906_f - ',df_201906_f.columns ,'\n')
print('df_201907_f - ',df_201907_f.columns ,'\n')
print('df_201908_f - ',df_201908_f.columns ,'\n')
print('df_201909_f - ',df_201909_f.columns ,'\n')
print('df_201910_f - ',df_201910_f.columns ,'\n')
print('df_201911_f - ',df_201911_f.columns ,'\n')
print('df_201912_f - ',df_201912_f.columns ,'\n')
print('df_201901_l - ',df_201901_l.columns ,'\n')
print('df_201902_l - ',df_201902_l.columns ,'\n')
print('df_201903_l - ',df_201903_l.columns ,'\n')
print('df_201904_l - ',df_201904_l.columns ,'\n')
print('df_201905_l - ',df_201905_l.columns ,'\n')
print('df_201906_l - ',df_201906_l.columns ,'\n')
print('df_201907_l - ',df_201907_l.columns ,'\n')
print('df_201908_l - ',df_201908_l.columns ,'\n')
print('df_201909_l - ',df_201909_l.columns ,'\n')
print('df_201910_l - ',df_201910_l.columns ,'\n')
print('df_201911_l - ',df_201911_l.columns ,'\n')
print('df_201912_l - ',df_201912_l.columns ,'\n')
print('df_202001_f - ',df_202001_f.columns ,'\n')
print('df_202002_f - ',df_202002_f.columns ,'\n')
print('df_202003_f - ',df_202003_f.columns ,'\n')
print('df_202004_f - ',df_202004_f.columns ,'\n')
print('df_202005_f - ',df_202005_f.columns ,'\n')
print('df_202006_f - ',df_202006_f.columns ,'\n')
print('df_202007_f - ',df_202007_f.columns ,'\n')
print('df_202008_f - ',df_202008_f.columns ,'\n')
print('df_202009_f - ',df_202009_f.columns ,'\n')
print('df_202010_f - ',df_202010_f.columns ,'\n')
print('df_202011_f - ',df_202011_f.columns ,'\n')
print('df_202012_f - ',df_202012_f.columns ,'\n')
print('df_202001_l - ',df_202001_l.columns ,'\n')
print('df_202002_l - ',df_202002_l.columns ,'\n')
print('df_202003_l - ',df_202003_l.columns ,'\n')
print('df_202004_l - ',df_202004_l.columns ,'\n')
print('df_202005_l - ',df_202005_l.columns ,'\n')
print('df_202006_l - ',df_202006_l.columns ,'\n')
print('df_202007_l - ',df_202007_l.columns ,'\n')
print('df_202008_l - ',df_202008_l.columns ,'\n')
print('df_202009_l - ',df_202009_l.columns ,'\n')
print('df_202010_l - ',df_202010_l.columns ,'\n')
print('df_202011_l - ',df_202011_l.columns ,'\n')
print('df_202012_l - ',df_202012_l.columns ,'\n')
print('df_202101_f - ',df_202101_f.columns ,'\n')
print('df_202102_f - ',df_202102_f.columns ,'\n')
print('df_202103_f - ',df_202103_f.columns ,'\n')
print('df_202104_f - ',df_202104_f.columns ,'\n')
print('df_202105_f - ',df_202105_f.columns ,'\n')
print('df_202102_l - ',df_202102_l.columns ,'\n')
print('df_202104_l - ',df_202104_l.columns ,'\n')
print('df_202105_l - ',df_202105_l.columns ,'\n')
# Out:
# df_201901_f -  Index(['MES', 'EQUIPAMENTO', 'FAIXA', 'DATA', 'HORA', 'MINUTOS_INTERVALO', 'QTD_0A10KM', 'QTD_11A20KM', 'QTD_21A30KM', 'QTD_31A40KM', 'QTD_41A50KM', 'QTD_51A60KM', 'QTD_61A70KM', 'QTD_71A80KM', 'QTD_81A90KM', 'QTD_91A100KM', 'QTD_ACIMADE100KM'], dtype='object')
#
# df_201902_f -  Index(['MES', 'EQUIPAMENTO', 'FAIXA', 'DATA', 'HORA', 'MINUTOS_INTERVALO', 'QTD_0A10KM', 'QTD_11A20KM', 'QTD_21A30KM', 'QTD_31A40KM', 'QTD_41A50KM', 'QTD_51A60KM', 'QTD_61A70KM', 'QTD_71A80KM', 'QTD_81A90KM', 'QTD_91A100KM', 'QTD_ACIMADE100KM'], dtype='object')
#
# df_201903_f -  Index(['MES', 'EQUIPAMENTO', 'FAIXA', 'DATA', 'HORA', 'MINUTOS_INTERVALO', 'QTD_0A10KM', 'QTD_11A20KM', 'QTD_21A30KM', 'QTD_31A40KM', 'QTD_41A50KM', 'QTD_51A60KM', 'QTD_61A70KM', 'QTD_71A80KM', 'QTD_81A90KM', 'QTD_91A100KM', 'QTD_ACIMADE100KM'], dtype='object')
#
# ...

# %% [markdown]
# Inserindo coluna de controle de ANO

# %%
df_201901_f.insert(0,"ANO",2019,True)
df_201902_f.insert(0,"ANO",2019,True)
df_201903_f.insert(0,"ANO",2019,True)
df_201904_f.insert(0,"ANO",2019,True)
df_201905_f.insert(0,"ANO",2019,True)
df_201906_f.insert(0,"ANO",2019,True)
df_201907_f.insert(0,"ANO",2019,True)
df_201908_f.insert(0,"ANO",2019,True)
df_201909_f.insert(0,"ANO",2019,True)
df_201910_f.insert(0,"ANO",2019,True)
df_201911_f.insert(0,"ANO",2019,True)
df_201912_f.insert(0,"ANO",2019,True)
df_202001_f.insert(0,"ANO",2020,True)
df_202002_f.insert(0,"ANO",2020,True)
df_202003_f.insert(0,"ANO",2020,True)
df_202004_f.insert(0,"ANO",2020,True)
df_202005_f.insert(0,"ANO",2020,True)
df_202006_f.insert(0,"ANO",2020,True)
df_202007_f.insert(0,"ANO",2020,True)
df_202008_f.insert(0,"ANO",2020,True)
df_202009_f.insert(0,"ANO",2020,True)
df_202010_f.insert(0,"ANO",2020,True)
df_202011_f.insert(0,"ANO",2020,True)
df_202012_f.insert(0,"ANO",2020,True)
df_202101_f.insert(0,"ANO",2021,True)
df_202102_f.insert(0,"ANO",2021,True)
df_202103_f.insert(0,"ANO",2021,True)
df_202104_f.insert(0,"ANO",2021,True)
df_202105_f.insert(0,"ANO",2021,True)

# %%
print('df_201901_f - ',df_201901_f.columns ,'\n')
print('df_201902_f - ',df_201902_f.columns ,'\n')
print('df_201903_f - ',df_201903_f.columns ,'\n')
print('df_201904_f - ',df_201904_f.columns ,'\n')
print('df_201905_f - ',df_201905_f.columns ,'\n')
print('df_201906_f - ',df_201906_f.columns ,'\n')
print('df_201907_f - ',df_201907_f.columns ,'\n')
print('df_201908_f - ',df_201908_f.columns ,'\n')
print('df_201909_f - ',df_201909_f.columns ,'\n')
print('df_201910_f - ',df_201910_f.columns ,'\n')
print('df_201911_f - ',df_201911_f.columns ,'\n')
print('df_201912_f - ',df_201912_f.columns ,'\n')
print('df_201901_l - ',df_201901_l.columns ,'\n')
print('df_201902_l - ',df_201902_l.columns ,'\n')
print('df_201903_l - ',df_201903_l.columns ,'\n')
print('df_201904_l - ',df_201904_l.columns ,'\n')
print('df_201905_l - ',df_201905_l.columns ,'\n')
print('df_201906_l - ',df_201906_l.columns ,'\n')
print('df_201907_l - ',df_201907_l.columns ,'\n')
print('df_201908_l - ',df_201908_l.columns ,'\n')
print('df_201909_l - ',df_201909_l.columns ,'\n')
print('df_201910_l - ',df_201910_l.columns ,'\n')
print('df_201911_l - ',df_201911_l.columns ,'\n')
print('df_201912_l - ',df_201912_l.columns ,'\n')
print('df_202001_f - ',df_202001_f.columns ,'\n')
print('df_202002_f - ',df_202002_f.columns ,'\n')
print('df_202003_f - ',df_202003_f.columns ,'\n')
print('df_202004_f - ',df_202004_f.columns ,'\n')
print('df_202005_f - ',df_202005_f.columns ,'\n')
print('df_202006_f - ',df_202006_f.columns ,'\n')
print('df_202007_f - ',df_202007_f.columns ,'\n')
print('df_202008_f - ',df_202008_f.columns ,'\n')
print('df_202009_f - ',df_202009_f.columns ,'\n')
print('df_202010_f - ',df_202010_f.columns ,'\n')
print('df_202011_f - ',df_202011_f.columns ,'\n')
print('df_202012_f - ',df_202012_f.columns ,'\n')
print('df_202001_l - ',df_202001_l.columns ,'\n')
print('df_202002_l - ',df_202002_l.columns ,'\n')
print('df_202003_l - ',df_202003_l.columns ,'\n')
print('df_202004_l - ',df_202004_l.columns ,'\n')
print('df_202005_l - ',df_202005_l.columns ,'\n')
print('df_202006_l - ',df_202006_l.columns ,'\n')
print('df_202007_l - ',df_202007_l.columns ,'\n')
print('df_202008_l - ',df_202008_l.columns ,'\n')
print('df_202009_l - ',df_202009_l.columns ,'\n')
print('df_202010_l - ',df_202010_l.columns ,'\n')
print('df_202011_l - ',df_202011_l.columns ,'\n')
print('df_202012_l - ',df_202012_l.columns ,'\n')
print('df_202101_f - ',df_202101_f.columns ,'\n')
print('df_202102_f - ',df_202102_f.columns ,'\n')
print('df_202103_f - ',df_202103_f.columns ,'\n')
print('df_202104_f - ',df_202104_f.columns ,'\n')
print('df_202105_f - ',df_202105_f.columns ,'\n')
print('df_202102_l - ',df_202102_l.columns ,'\n')
print('df_202104_l - ',df_202104_l.columns ,'\n')
print('df_202105_l - ',df_202105_l.columns ,'\n')
# Out:
# df_201901_f -  Index(['ANO', 'MES', 'EQUIPAMENTO', 'FAIXA', 'DATA', 'HORA', 'MINUTOS_INTERVALO', 'QTD_0A10KM', 'QTD_11A20KM', 'QTD_21A30KM', 'QTD_31A40KM', 'QTD_41A50KM', 'QTD_51A60KM', 'QTD_61A70KM', 'QTD_71A80KM', 'QTD_81A90KM', 'QTD_91A100KM', 'QTD_ACIMADE100KM'], dtype='object')
#
# df_201902_f -  Index(['ANO', 'MES', 'EQUIPAMENTO', 'FAIXA', 'DATA', 'HORA', 'MINUTOS_INTERVALO', 'QTD_0A10KM', 'QTD_11A20KM', 'QTD_21A30KM', 'QTD_31A40KM', 'QTD_41A50KM', 'QTD_51A60KM', 'QTD_61A70KM', 'QTD_71A80KM', 'QTD_81A90KM', 'QTD_91A100KM', 'QTD_ACIMADE100KM'], dtype='object')
#
# df_201903_f -  Index(['ANO', 'MES', 'EQUIPAMENTO', 'FAIXA', 'DATA', 'HORA', 'MINUTOS_INTERVALO', 'QTD_0A10KM', 'QTD_11A20KM', 'QTD_21A30KM', 'QTD_31A40KM', 'QTD_41A50KM', 'QTD_51A60KM', 'QTD_61A70KM', 'QTD_71A80KM', 'QTD_81A90KM', 'QTD_91A100KM', 'QTD_ACIMADE100KM'], dtype='object')
#
# ...

# %%
print('df_201901_f - ',df_201901_f.dtypes ,'\n')
print('df_201902_f - ',df_201902_f.dtypes ,'\n')
print('df_201903_f - ',df_201903_f.dtypes ,'\n')
print('df_201904_f - ',df_201904_f.dtypes ,'\n')
print('df_201905_f - ',df_201905_f.dtypes ,'\n')
print('df_201906_f - ',df_201906_f.dtypes ,'\n')
print('df_201907_f - ',df_201907_f.dtypes ,'\n')
print('df_201908_f - ',df_201908_f.dtypes ,'\n')
print('df_201909_f - ',df_201909_f.dtypes ,'\n')
print('df_201910_f - ',df_201910_f.dtypes ,'\n')
print('df_201911_f - ',df_201911_f.dtypes ,'\n')
print('df_201912_f - ',df_201912_f.dtypes ,'\n')
print('df_201901_l - ',df_201901_l.dtypes ,'\n')
print('df_201902_l - ',df_201902_l.dtypes ,'\n')
print('df_201903_l - ',df_201903_l.dtypes ,'\n')
print('df_201904_l - ',df_201904_l.dtypes ,'\n')
print('df_201905_l - ',df_201905_l.dtypes ,'\n')
print('df_201906_l - ',df_201906_l.dtypes ,'\n')
print('df_201907_l - ',df_201907_l.dtypes ,'\n')
print('df_201908_l - ',df_201908_l.dtypes ,'\n')
print('df_201909_l - ',df_201909_l.dtypes ,'\n')
print('df_201910_l - ',df_201910_l.dtypes ,'\n')
print('df_201911_l - ',df_201911_l.dtypes ,'\n')
print('df_201912_l - ',df_201912_l.dtypes ,'\n')
print('df_202001_f - ',df_202001_f.dtypes ,'\n')
print('df_202002_f - ',df_202002_f.dtypes ,'\n')
print('df_202003_f - ',df_202003_f.dtypes ,'\n')
print('df_202004_f - ',df_202004_f.dtypes ,'\n')
print('df_202005_f - ',df_202005_f.dtypes ,'\n')
print('df_202006_f - ',df_202006_f.dtypes ,'\n')
print('df_202007_f - ',df_202007_f.dtypes ,'\n')
print('df_202008_f - ',df_202008_f.dtypes ,'\n')
print('df_202009_f - ',df_202009_f.dtypes ,'\n')
print('df_202010_f - ',df_202010_f.dtypes ,'\n')
print('df_202011_f - ',df_202011_f.dtypes ,'\n')
print('df_202012_f - ',df_202012_f.dtypes ,'\n')
print('df_202001_l - ',df_202001_l.dtypes ,'\n')
print('df_202002_l - ',df_202002_l.dtypes ,'\n')
print('df_202003_l - ',df_202003_l.dtypes ,'\n')
print('df_202004_l - ',df_202004_l.dtypes ,'\n')
print('df_202005_l - ',df_202005_l.dtypes ,'\n')
print('df_202006_l - ',df_202006_l.dtypes ,'\n')
print('df_202007_l - ',df_202007_l.dtypes ,'\n')
print('df_202008_l - ',df_202008_l.dtypes ,'\n')
print('df_202009_l - ',df_202009_l.dtypes ,'\n')
print('df_202010_l - ',df_202010_l.dtypes ,'\n')
print('df_202011_l - ',df_202011_l.dtypes ,'\n')
print('df_202012_l - ',df_202012_l.dtypes ,'\n')
print('df_202101_f - ',df_202101_f.dtypes ,'\n')
print('df_202102_f - ',df_202102_f.dtypes ,'\n')
print('df_202103_f - ',df_202103_f.dtypes ,'\n')
print('df_202104_f - ',df_202104_f.dtypes ,'\n')
print('df_202105_f - ',df_202105_f.dtypes ,'\n')
print('df_202102_l - ',df_202102_l.dtypes ,'\n')
print('df_202104_l - ',df_202104_l.dtypes ,'\n')
print('df_202105_l - ',df_202105_l.dtypes ,'\n')
# Out:
# df_201901_f -  ANO                    int64
# MES                    int64
# EQUIPAMENTO           object
# FAIXA                  int64
# DATA                  object
# HORA                   int64
# MINUTOS_INTERVALO     object
# QTD_0A10KM             int64
# QTD_11A20KM            int64
# QTD_21A30KM          float64
# QTD_31A40KM          float64
# QTD_41A50KM          float64
# QTD_51A60KM          float64
# QTD_61A70KM          float64
# QTD_71A80KM          float64
# QTD_81A90KM          float64
# QTD_91A100KM         float64
# QTD_ACIMADE100KM     float64
# dtype: object
#
# df_201902_f -  ANO                    int64
# MES                    int64
# EQUIPAMENTO           object
# FAIXA                  int64
# DATA                  object
# HORA                   int64
# MINUTOS_INTERVALO     object
# QTD_0A10KM             int64
# QTD_11A20KM            int64
# QTD_21A30KM            int64
# QTD_31A40KM            int64
# QTD_41A50KM            int64
# ...

# %% [markdown]
# Padronizando o ***type*** das colunas para poder realizar as unificações

# %%
df_201901_f = df_201901_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201902_f = df_201902_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201903_f = df_201903_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201904_f = df_201904_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201905_f = df_201905_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201906_f = df_201906_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201907_f = df_201907_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201908_f = df_201908_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201909_f = df_201909_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201910_f = df_201910_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201911_f = df_201911_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201912_f = df_201912_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201901_l = df_201901_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201902_l = df_201902_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201903_l = df_201903_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201904_l = df_201904_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201905_l = df_201905_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201906_l = df_201906_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201907_l = df_201907_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object}, errors='ignore')

df_201908_l = df_201908_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201909_l = df_201909_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201910_l = df_201910_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201911_l = df_201911_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_201912_l = df_201912_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202001_f = df_202001_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202002_f = df_202002_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202003_f = df_202003_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202004_f = df_202004_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202005_f = df_202005_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202006_f = df_202006_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202007_f = df_202007_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202008_f = df_202008_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202009_f = df_202009_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202010_f = df_202010_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202011_f = df_202011_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202012_f = df_202012_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202001_l = df_202001_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202002_l = df_202002_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202003_l = df_202003_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202004_l = df_202004_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202005_l = df_202005_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202006_l = df_202006_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202007_l = df_202007_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202008_l = df_202008_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202009_l = df_202009_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202010_l = df_202010_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202011_l = df_202011_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202012_l = df_202012_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202101_f = df_202101_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202102_f = df_202102_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202103_f = df_202103_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202104_f = df_202104_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202105_f = df_202105_f.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202102_l = df_202102_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202104_l = df_202104_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

df_202105_l = df_202105_l.astype({"ANO":int, "MES":int, "EQUIPAMENTO":object, "FAIXA":object, "DATA":object, "HORA":object, "MINUTOS_INTERVALO":object, "QTD_0A10KM":object, "QTD_11A20KM":object,
"QTD_21A30KM":object, "QTD_31A40KM":object, "QTD_41A50KM":object, "QTD_51A60KM":object, "QTD_61A70KM":object, "QTD_71A80KM":object, "QTD_81A90KM":object, "QTD_91A100KM":object,"QTD_ACIMADE100KM":object})

# %%
df_201907_l.head(10)
# Out:
#     ANO  MES EQUIPAMENTO FAIXA        DATA HORA MINUTOS_INTERVALO QTD_0A10KM QTD_11A20KM QTD_21A30KM QTD_31A40KM QTD_41A50KM QTD_51A60KM QTD_61A70KM QTD_71A80KM QTD_81A90KM QTD_91A100KM QTD_ACIMADE100KM
# 0  2019  7.0           1     1  2019-07-02   10       10:00-10:15          0           0           2          16         143          33           1           0           0            0                0
# 1  2019  7.0           1     1  2019-07-02   10       10:15-10:30          0           0           0          19         132          31           3           0           0            0                0
# 2  2019  7.0           1     1  2019-07-02   10       10:30-10:45          0           0           0          13         136          39           4           0           0            0                0
# ...

# %% [markdown]
# Unificando as tabelas

# %%
df_union = [df_2016[df_202105_f.columns],df_2017[df_202105_f.columns],df_2018[df_202105_f.columns],df_201901_f[df_202105_f.columns],df_201902_f[df_202105_f.columns],df_201903_f[df_202105_f.columns],df_201904_f[df_202105_f.columns],df_201905_f[df_202105_f.columns],df_201906_f[df_202105_f.columns],df_201907_f[df_202105_f.columns],df_201908_f[df_202105_f.columns],df_201909_f[df_202105_f.columns],df_201910_f[df_202105_f.columns],df_201911_f[df_202105_f.columns],df_201912_f[df_202105_f.columns],df_201901_l[df_202105_f.columns],df_201902_l[df_202105_f.columns],df_201903_l[df_202105_f.columns],
df_201904_l[df_202105_f.columns],df_201905_l[df_202105_f.columns],df_201906_l[df_202105_f.columns],df_201907_l[df_202105_f.columns],df_201908_l[df_202105_f.columns],df_201909_l[df_202105_f.columns],df_201910_l[df_202105_f.columns],df_201911_l[df_202105_f.columns],df_201912_l[df_202105_f.columns],df_202001_f[df_202105_f.columns],df_202002_f[df_202105_f.columns],df_202003_f[df_202105_f.columns],df_202004_f[df_202105_f.columns],df_202005_f[df_202105_f.columns],df_202006_f[df_202105_f.columns],
df_202007_f[df_202105_f.columns],df_202008_f[df_202105_f.columns],df_202009_f[df_202105_f.columns],df_202010_f[df_202105_f.columns],df_202011_f[df_202105_f.columns],df_202012_f[df_202105_f.columns],df_202001_l[df_202105_f.columns],df_202002_l[df_202105_f.columns],df_202003_l[df_202105_f.columns],df_202004_l[df_202105_f.columns],df_202005_l[df_202105_f.columns],df_202006_l[df_202105_f.columns],df_202007_l[df_202105_f.columns],df_202008_l[df_202105_f.columns],df_202009_l[df_202105_f.columns],
df_202010_l[df_202105_f.columns],df_202011_l[df_202105_f.columns],df_202012_l[df_202105_f.columns],df_202101_f[df_202105_f.columns],df_202102_f[df_202105_f.columns],df_202103_f[df_202105_f.columns],df_202104_f[df_202105_f.columns],df_202105_f[df_202105_f.columns],df_202102_l[df_202105_f.columns],df_202104_l[df_202105_f.columns],df_202105_l[df_202105_f.columns]]

df_final = pd.concat(df_union)

# %%
df_final['ANO'].unique()
# Out:
# array([2016, 2017, 2018, 2019, 2020, 2021])

# %% [markdown]
# Salvando tabela ....

# %%
df_final.to_csv(r'velocidade_vias_media_15minutos_2016_2021.csv', sep=';' , index = False )

# %% [markdown]
# Código para verificação de colunas até a que ocorre o erro

# %%
import csv
#88408
nrows=88406
a = 0
with open('/content/velocidades_vias_velocidade_media_15min_201902_l.csv','rt') as f:
    csv_reader = csv.reader(f,delimiter=';')

    for line in csv_reader:
        a = a+1
        print(line)
    print(a , '\n')
  
#pd.read_csv("/content/velocidades_vias_velocidade_media_15min_201902_l.csv", delimiter=';', skiprows=88408,nrows=94508, low_memory=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# ['2019', '2', '5953', '2', '2019-02-09', '22', '22:30-22:45', '3', '14', '40', '6', '0', '0', '0', '0', '0', '0', '0']
# ['2019', '2', '5954', '1', '2019-02-09', '22', '22:30-22:45', '3', '58', '59', '4', '0', '0', '0', '0', '0', '0', '0']
# ['2019', '2', '5953', '2', '2019-02-09', '22', '22:45-23:00', '0', '12', '35', '4', '0', '0', '0', '0', '0', '0', '0']
# ['2019', '2', '5954', '1', '2019-02-09', '22', '22:45-23:00', '0', '33', '51', '2', '0', '0', '0', '0', '0', '0', '0']
# ['2019', '2', '5953', '2', '2019-02-09', '23', '23:00-23:15', '0', '12', '29', '9', '0', '0', '0', '0', '0', '0', '1']
# ['2019', '2', '5954', '1', '2019-02-09', '23', '23:00-23:15', '0', '32', '46', '6', '1', '1', '0', '0', '0', '0', '0']
# ['2019', '2', '5953', '2', '2019-02-09', '23', '23:15-23:30', '1', '5', '27', '3', '1', '0', '0', '0', '0', '0', '0']
# ...

# %% [markdown]
# # Velocidades de Vias - Equipamentos

# %%
df_2016 = pd.read_csv("/content/equipamento_velocidades_vias_2016.csv", delimiter=';',low_memory=False)
df_2016.columns = map(str.upper, df_2016.columns)
print('2016 - ' , df_2016.columns)

df_2017 = pd.read_csv("/content/equipamento_velocidades_vias_2017.csv", delimiter=';',low_memory=False)
df_2017.columns = map(str.upper, df_2017.columns)
print('2017 - ' , df_2017.columns)

df_2018 = pd.read_csv("/content/equipamento_velocidades_vias_2018.csv", delimiter=';',low_memory=False)
df_2018.columns = map(str.upper, df_2018.columns)
print('2016 - ' , df_2018.columns)

df_2019 = pd.read_csv("/content/equipamento_velocidades_vias_2019.csv", delimiter=';',low_memory=False)
df_2019.columns = map(str.upper, df_2019.columns)
print('2019 - ' , df_2019.columns)

df_2020 = pd.read_csv("/content/equipamento_velocidades_vias_2020.csv", delimiter=';',low_memory=False)
df_2020.columns = map(str.upper, df_2020.columns)
print('2020 - ' , df_2020.columns)

df_2021 = pd.read_csv("/content/equipamento_velocidades_vias_2021.csv", delimiter=';',low_memory=False)
df_2021.columns = map(str.upper, df_2021.columns)
print('2021 - ' , df_2021.columns)
# Out:
# 2016 -  Index(['EQUIPAMENTO', 'TIPO', 'LOGRADOURO', 'VELOCIDADE_VIA', 'LATITUDE', 'LONGITUDE'], dtype='object')
# 2017 -  Index(['EQUIPAMENTO', 'TIPO', 'LOGRADOURO', 'VELOCIDADE_VIA', 'LATITUDE', 'LONGITUDE'], dtype='object')
# 2016 -  Index(['EQUIPAMENTO', 'TIPO', 'LOGRADOURO', 'VELOCIDADE_VIA', 'LATITUDE', 'LONGITUDE'], dtype='object')
# 2019 -  Index(['EQUIPAMENTO', 'TIPO', 'LOGRADOURO', 'VELOCIDADE_VIA', 'LATITUDE', 'LONGITUDE'], dtype='object')
# 2020 -  Index(['EQUIPAMENTO', 'TIPO', 'LOGRADOURO', 'VELOCIDADE_VIA', 'LATITUDE', 'LONGITUDE'], dtype='object')
# 2021 -  Index(['EQUIPAMENTO', 'TIPO', 'LOGRADOURO', 'VELOCIDADE_VIA', 'LATITUDE', 'LONGITUDE'], dtype='object')

# %% [markdown]
# Layouts estando ok, agora é realizado uma verificação do tipo das colunas

# %%
print('2016 - ' , df_2016.dtypes,'\n')
print('2017 - ' , df_2017.dtypes,'\n')
print('2016 - ' , df_2018.dtypes,'\n')
print('2019 - ' , df_2019.dtypes,'\n')
print('2020 - ' , df_2020.dtypes,'\n')
print('2021 - ' , df_2021.dtypes,'\n')
# Out:
# 2016 -  EQUIPAMENTO        object
# TIPO               object
# LOGRADOURO         object
# VELOCIDADE_VIA     object
# LATITUDE          float64
# LONGITUDE         float64
# dtype: object
#
# 2017 -  EQUIPAMENTO        object
# TIPO               object
# LOGRADOURO         object
# VELOCIDADE_VIA     object
# LATITUDE          float64
# LONGITUDE         float64
# dtype: object
#
# 2016 -  EQUIPAMENTO        object
# TIPO               object
# LOGRADOURO         object
# VELOCIDADE_VIA     object
# LATITUDE          float64
# LONGITUDE         float64
# dtype: object
#
# 2019 -  EQUIPAMENTO        object
# TIPO               object
# LOGRADOURO         object
# VELOCIDADE_VIA     object
# LATITUDE          float64
# LONGITUDE         float64
# dtype: object
#
# 2020 -  EQUIPAMENTO        object
# TIPO               object
# LOGRADOURO         object
# VELOCIDADE_VIA     object
# LATITUDE          float64
# LONGITUDE         float64
# dtype: object
#
# ...

# %%
df_2016.head(5)
# Out:
#   EQUIPAMENTO     TIPO                                         LOGRADOURO VELOCIDADE_VIA  LATITUDE  LONGITUDE
# 0        5941  Lombada  AV. MAL. MASCARENHAS DE MORAES, EM FRENTE AERO...        60 km/h -8.130970 -34.916161
# 1        5942  Lombada  AV. MAL. MASCARENHAS DE MORAES, EM FRENTE AERO...        60 km/h -8.130647 -34.915886
# 2        5943  Lombada                   AV. BOA VIAGEM - TERCEIRO JARDIM        60 km/h -8.107843 -34.888161
# 3        5944  Lombada  DEFRONTE A PCA. GOV. PAULO GUERRA, CABANGA - S...        60 km/h -8.080121 -34.892187
# 4        5945  Lombada  APOS PONTE AGAMENON MAGALHAES, CABANGA - SENT....        60 km/h -8.080820 -34.891159

# %% [markdown]
# Adicionando coluna de controle do ANO DO ARQUIVO

# %%
df_2016.insert(0,"ANO",2016,True)
df_2017.insert(0,"ANO",2017,True)
df_2018.insert(0,"ANO",2018,True)
df_2019.insert(0,"ANO",2019,True)
df_2020.insert(0,"ANO",2020,True)
df_2021.insert(0,"ANO",2021,True)

# %%
print('2016 - ' , df_2016.columns)
print('2017 - ' , df_2017.columns)
print('2018 - ' , df_2018.columns)
print('2019 - ' , df_2019.columns)
print('2020 - ' , df_2020.columns)
print('2021 - ' , df_2021.columns)
# Out:
# 2016 -  Index(['ANO', 'EQUIPAMENTO', 'TIPO', 'LOGRADOURO', 'VELOCIDADE_VIA', 'LATITUDE', 'LONGITUDE'], dtype='object')
# 2017 -  Index(['ANO', 'EQUIPAMENTO', 'TIPO', 'LOGRADOURO', 'VELOCIDADE_VIA', 'LATITUDE', 'LONGITUDE'], dtype='object')
# 2018 -  Index(['ANO', 'EQUIPAMENTO', 'TIPO', 'LOGRADOURO', 'VELOCIDADE_VIA', 'LATITUDE', 'LONGITUDE'], dtype='object')
# 2019 -  Index(['ANO', 'EQUIPAMENTO', 'TIPO', 'LOGRADOURO', 'VELOCIDADE_VIA', 'LATITUDE', 'LONGITUDE'], dtype='object')
# 2020 -  Index(['ANO', 'EQUIPAMENTO', 'TIPO', 'LOGRADOURO', 'VELOCIDADE_VIA', 'LATITUDE', 'LONGITUDE'], dtype='object')
# 2021 -  Index(['ANO', 'EQUIPAMENTO', 'TIPO', 'LOGRADOURO', 'VELOCIDADE_VIA', 'LATITUDE', 'LONGITUDE'], dtype='object')

# %%
df_2016.head(5)
# Out:
#     ANO EQUIPAMENTO     TIPO                                         LOGRADOURO VELOCIDADE_VIA  LATITUDE  LONGITUDE
# 0  2016        5941  Lombada  AV. MAL. MASCARENHAS DE MORAES, EM FRENTE AERO...        60 km/h -8.130970 -34.916161
# 1  2016        5942  Lombada  AV. MAL. MASCARENHAS DE MORAES, EM FRENTE AERO...        60 km/h -8.130647 -34.915886
# 2  2016        5943  Lombada                   AV. BOA VIAGEM - TERCEIRO JARDIM        60 km/h -8.107843 -34.888161
# 3  2016        5944  Lombada  DEFRONTE A PCA. GOV. PAULO GUERRA, CABANGA - S...        60 km/h -8.080121 -34.892187
# 4  2016        5945  Lombada  APOS PONTE AGAMENON MAGALHAES, CABANGA - SENT....        60 km/h -8.080820 -34.891159

# %% [markdown]
# Unificação das tabelas

# %%
df_union = [df_2016[df_2021.columns], df_2017[df_2021.columns], df_2018[df_2021.columns], df_2019[df_2021.columns], df_2020[df_2021.columns], df_2021[df_2021.columns]]

df_final = pd.concat(df_union)

# %%
df_final['ANO'].unique()
# Out:
# array([2016, 2017, 2018, 2019, 2020, 2021])

# %%
df_final.count()
# Out:
# ANO               372
# EQUIPAMENTO       372
# TIPO              372
# LOGRADOURO        372
# VELOCIDADE_VIA    372
# LATITUDE          372
# LONGITUDE         372
# dtype: int64

# %% [markdown]
# Salvando tabela ...

# %%
df_final.to_csv(r'equipamento_velocidade_vias_2016_2021.csv', sep=';' , index = False )

# %% [markdown]
# # Comercios - Bares e Restaurantes

# %%
df_202101_t = pd.read_csv("comercios_202101_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_202101_t.columns = map(str.upper, df_202101_t.columns)
print("202101 - " , df_202101_t.columns,'\n')

df_202004_t = pd.read_csv("comercios_202004_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_202004_t.columns = map(str.upper, df_202004_t.columns)
print("202004 - " , df_202004_t.columns,'\n')

df_202003_t = pd.read_csv("comercios_202003_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_202003_t.columns = map(str.upper, df_202003_t.columns)
print("202003 - " , df_202003_t.columns,'\n')

df_202001_t = pd.read_csv("comercios_202001_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_202001_t.columns = map(str.upper, df_202001_t.columns)
print("202001 - " , df_202001_t.columns,'\n')

df_201901_t = pd.read_csv("comercios_201901_trimestre.csv", delimiter=';',encoding='UTF-8',error_bad_lines=False)
df_201901_t.columns = map(str.upper, df_201901_t.columns)
print("201901 - " , df_201901_t.columns,'\n')

df_201902_t = pd.read_csv("comercios_201902_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_201902_t.columns = map(str.upper, df_201902_t.columns)
print("201902 - " , df_201902_t.columns,'\n')

df_201903_t = pd.read_csv("comercios_201903_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_201903_t.columns = map(str.upper, df_201903_t.columns)
print("201903 - " , df_201903_t.columns,'\n')

df_201904_t = pd.read_csv("comercios_201904_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_201904_t.columns = map(str.upper, df_201904_t.columns)
print("201904 - " , df_201904_t.columns,'\n')

df_201804_t = pd.read_csv("comercios_201804_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_201804_t.columns = map(str.upper, df_201804_t.columns)
print("201804 - " , df_201804_t.columns,'\n')

df_201803_t = pd.read_csv("comercios_201803_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_201803_t.columns = map(str.upper, df_201803_t.columns)
print("201803 - " , df_201803_t.columns,'\n')

df_201802_t = pd.read_csv("comercios_201802_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_201802_t.columns = map(str.upper, df_201802_t.columns)
print("201802 - " , df_201802_t.columns,'\n')

df_201801_t = pd.read_csv("comercios_201801_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_201801_t.columns = map(str.upper, df_201801_t.columns)
print("201801 - " , df_201801_t.columns,'\n')

df_201704_t = pd.read_csv("comercios_201704_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_201704_t.columns = map(str.upper, df_201704_t.columns)
print("201704 - " , df_201704_t.columns,'\n')

df_201703_t = pd.read_csv("comercios_201703_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_201703_t.columns = map(str.upper, df_201703_t.columns)
print("201703 - " , df_201703_t.columns,'\n')

df_201702_t = pd.read_csv("comercios_201702_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_201702_t.columns = map(str.upper, df_201702_t.columns)
print("201702 - " , df_201702_t.columns,'\n')

df_201701_t = pd.read_csv("comercios_201701_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_201701_t.columns = map(str.upper, df_201701_t.columns)
print("201701 - " , df_201701_t.columns,'\n')

df_201604_t = pd.read_csv("comercios_201604_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_201604_t.columns = map(str.upper, df_201604_t.columns)
print("201604 - " , df_201604_t.columns,'\n')

df_201603_t = pd.read_csv("comercios_201603_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_201603_t.columns = map(str.upper, df_201603_t.columns)
print("201603 - " , df_201603_t.columns,'\n')

df_201602_t = pd.read_csv("comercios_201602_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_201602_t.columns = map(str.upper, df_201602_t.columns)
print("201602 - " , df_201602_t.columns,'\n')

df_201601_t = pd.read_csv("comercios_201601_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_201601_t.columns = map(str.upper, df_201601_t.columns)
print("201601 - " , df_201601_t.columns,'\n')

df_2015_t = pd.read_csv("comercios_2015_trimestre.csv", delimiter=';',encoding='ISO-8859-1',error_bad_lines=False)
df_2015_t.columns = map(str.upper, df_2015_t.columns)
print("202101 - " , df_2015_t.columns,'\n')
# Out:
# 202101 -  Index(['RAZÃO SOCIAL', 'NOME FANTASIA', 'CNPJ', 'PORTE', 'DATA DE INICIO DA OPERAÇÃO', 'SITUAÇÃO', 'ATIVIDADE', 'CEP', 'UF', 'LOCALIDADE', 'BAIRRO', 'LOGRADOURO', 'COMPLEMENTO', 'SITE', 'DATA DE GERAÇÃO DO CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO', 'CÓDIGO DO CERTIFICADO', 'CNAE', 'TIPO DE ATIVIDADE', 'NATUREZA JURÍDICA', 'LÍNGUAS', 'ESPECIALIDADES', 'UNNAMED: 22', 'UNNAMED: 23', 'UNNAMED: 24'], dtype='object')
#
# 202004 -  Index(['RAZÃO SOCIAL', 'NOME FANTASIA', 'CNPJ', 'PORTE', 'DATA DE INICIO DA OPERAÇÃO', 'SITUAÇÃO', 'ATIVIDADE', 'CEP', 'UF', 'LOCALIDADE', 'BAIRRO', 'LOGRADOURO', 'COMPLEMENTO', 'SITE', 'DATA DE GERAÇÃO DO CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO', 'CÓDIGO DO CERTIFICADO', 'CNAE', 'TIPO DE ATIVIDADE', 'NATUREZA JURÍDICA', 'LÍNGUAS', 'ESPECIALIDADES', 'UNNAMED: 22', 'UNNAMED: 23', 'UNNAMED: 24'], dtype='object')
# ...

# %%
df_202004_t.head(5)
# Out:
#                                        RAZÃO SOCIAL                 NOME FANTASIA                CNPJ                     PORTE DATA DE INICIO DA OPERAÇÃO     SITUAÇÃO                                ATIVIDADE        CEP  UF LOCALIDADE         BAIRRO                  LOGRADOURO COMPLEMENTO                           SITE DATA DE GERAÇÃO DO CERTIFICADO DATA DE VALIDADE DO CERTIFICADO CÓDIGO DO CERTIFICADO                                               CNAE TIPO DE ATIVIDADE              NATUREZA JURÍDICA   LÍNGUAS       ESPECIALIDADES UNNAMED: 22 UNNAMED: 23 UNNAMED: 24
# ...

# %% [markdown]
# Verificando layout das tabelas

# %%
print('202101 ' , df_202101_t.columns,'\n')
print('202004 ' , df_202004_t.columns,'\n')
print('202003 ' , df_202003_t.columns,'\n')
print('202001 ' , df_202001_t.columns,'\n')
print('201901 ' , df_201901_t.columns,'\n')
print('201902 ' , df_201902_t.columns,'\n')
print('201903 ' , df_201903_t.columns,'\n')
print('201904 ' , df_201904_t.columns,'\n')
print('201804 ' , df_201804_t.columns,'\n')
print('201803 ' , df_201803_t.columns,'\n')
print('201802 ' , df_201802_t.columns,'\n')
print('201801 ' , df_201801_t.columns,'\n')
print('201704 ' , df_201704_t.columns,'\n')
print('201703 ' , df_201703_t.columns,'\n')
print('201702 ' , df_201702_t.columns,'\n')
print('201701 ' , df_201701_t.columns,'\n')
print('201604 ' , df_201604_t.columns,'\n')
print('201603 ' , df_201603_t.columns,'\n')
print('201602 ' , df_201602_t.columns,'\n')
print('201601 ' , df_201601_t.columns,'\n')
print('2015 ' , df_2015_t.columns,'\n')
# Out:
# 202101  Index(['RAZÃO SOCIAL', 'NOME FANTASIA', 'CNPJ', 'PORTE', 'DATA DE INICIO DA OPERAÇÃO', 'SITUAÇÃO', 'ATIVIDADE', 'CEP', 'UF', 'LOCALIDADE', 'BAIRRO', 'LOGRADOURO', 'COMPLEMENTO', 'SITE', 'DATA DE GERAÇÃO DO CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO', 'CÓDIGO DO CERTIFICADO', 'CNAE', 'TIPO DE ATIVIDADE', 'NATUREZA JURÍDICA', 'LÍNGUAS', 'ESPECIALIDADES', 'UNNAMED: 22', 'UNNAMED: 23', 'UNNAMED: 24'], dtype='object')
#
# 202004  Index(['RAZÃO SOCIAL', 'NOME FANTASIA', 'CNPJ', 'PORTE', 'DATA DE INICIO DA OPERAÇÃO', 'SITUAÇÃO', 'ATIVIDADE', 'CEP', 'UF', 'LOCALIDADE', 'BAIRRO', 'LOGRADOURO', 'COMPLEMENTO', 'SITE', 'DATA DE GERAÇÃO DO CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO', 'CÓDIGO DO CERTIFICADO', 'CNAE', 'TIPO DE ATIVIDADE', 'NATUREZA JURÍDICA', 'LÍNGUAS', 'ESPECIALIDADES', 'UNNAMED: 22', 'UNNAMED: 23', 'UNNAMED: 24'], dtype='object')
#
# ...

# %% [markdown]
# Adicionando colunas para controle do ANO DO ARQUIVO e MES DO ARQUIVO, assim como algumas colunas faltantes em alguns anos para unificação de layout

# %%
df_202101_t[['ANO','TRIMESTRE']] = [2021,1]
df_202004_t[['ANO','TRIMESTRE']] = [2020,4]
df_202003_t[['ANO','TRIMESTRE']] = [2020,3]
df_202001_t[['ANO','TRIMESTRE']] = [2020,1]
df_201901_t[['ANO','TRIMESTRE']] = [2019,1]
df_201902_t[['ANO','TRIMESTRE']] = [2019,2]
df_201903_t[['ANO','TRIMESTRE']] = [2019,3]
df_201904_t[['ANO','TRIMESTRE']] = [2019,4]
df_201804_t[['ANO','TRIMESTRE']] = [2018,4]
df_201803_t[['ANO','TRIMESTRE']] = [2018,3]
df_201802_t[['ANO','TRIMESTRE']] = [2018,2]
df_201801_t[['ANO','TRIMESTRE']] = [2018,1]
df_201704_t[['ANO','TRIMESTRE','COMPLEMENTO', 'DATA_GERACAO_CERTIFICADO','DATA_VALIDADE_CERTIFICADO']] = [2017,4,np.nan,np.nan,np.nan]
df_201703_t[['ANO','TRIMESTRE','COMPLEMENTO', 'DATA_GERACAO_CERTIFICADO','DATA_VALIDADE_CERTIFICADO']] = [2017,3,np.nan,np.nan,np.nan]
df_201702_t[['ANO','TRIMESTRE','COMPLEMENTO', 'DATA_GERACAO_CERTIFICADO','DATA_VALIDADE_CERTIFICADO']] = [2017,2,np.nan,np.nan,np.nan]
df_201701_t[['ANO','TRIMESTRE','COMPLEMENTO', 'DATA_GERACAO_CERTIFICADO','DATA_VALIDADE_CERTIFICADO']] = [2017,1,np.nan,np.nan,np.nan]
df_201604_t[['ANO','TRIMESTRE','COMPLEMENTO', 'DATA_GERACAO_CERTIFICADO','DATA_VALIDADE_CERTIFICADO']] = [2016,4,np.nan,np.nan,np.nan]
df_201603_t[['ANO','TRIMESTRE','COMPLEMENTO', 'DATA_GERACAO_CERTIFICADO','DATA_VALIDADE_CERTIFICADO']] = [2016,3,np.nan,np.nan,np.nan]
df_201602_t[['ANO','TRIMESTRE','COMPLEMENTO']] = [2016,2,np.nan]
df_201601_t[['ANO','TRIMESTRE','COMPLEMENTO']] = [2016,1,np.nan]
df_2015_t[['ANO','TRIMESTRE','COMPLEMENTO', 'DATA_GERACAO_CERTIFICADO','DATA_VALIDADE_CERTIFICADO']] = [2015,0,np.nan,np.nan,np.nan]

# %% [markdown]
# Selecionando quais colunas utilizar para unificação de layouts

# %%
select_columns = ['ANO','TRIMESTRE','RAZAO_SOCIAL','NOME_FANTASIA','CNPJ','PORTE','DATA_INICIO_OPERACAO','SITUACAO','ATIVIDADE','CEP', 'UF', 'LOCALIDADE', 'BAIRRO', 'LOGRADOURO','DATA_GERACAO_CERTIFICADO', 'DATA_VALIDADE_CERTIFICADO','CODIGO_CERTIFICADO','CODIGO_DESCRICAO_CNAE','NATUREZA_JURIDICA']

# %%
df_202101_t2 = df_202101_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA DE INICIO DA OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'DATA DE GERAÇÃO DO CERTIFICADO':'DATA_GERACAO_CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO':'DATA_VALIDADE_CERTIFICADO', 'CÓDIGO DO CERTIFICADO':'CODIGO_CERTIFICADO', 'CNAE':'CODIGO_DESCRICAO_CNAE',   'NATUREZA JURÍDICA':"NATUREZA_JURIDICA"})[select_columns]
df_202004_t2 = df_202004_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA DE INICIO DA OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'DATA DE GERAÇÃO DO CERTIFICADO':'DATA_GERACAO_CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO':'DATA_VALIDADE_CERTIFICADO', 'CÓDIGO DO CERTIFICADO':'CODIGO_CERTIFICADO', 'CNAE':'CODIGO_DESCRICAO_CNAE',   'NATUREZA JURÍDICA':"NATUREZA_JURIDICA"})[select_columns]
df_202003_t2 = df_202003_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA DE INICIO DA OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'DATA DE GERAÇÃO DO CERTIFICADO':'DATA_GERACAO_CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO':'DATA_VALIDADE_CERTIFICADO', 'CÓDIGO DO CERTIFICADO':'CODIGO_CERTIFICADO', 'CNAE':'CODIGO_DESCRICAO_CNAE',   'NATUREZA JURÍDICA':"NATUREZA_JURIDICA"})[select_columns]
df_202001_t2 = df_202001_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA DE INICIO DA OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'DATA DE GERAÇÃO DO CERTIFICADO':'DATA_GERACAO_CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO':'DATA_VALIDADE_CERTIFICADO', 'CÓDIGO DO CERTIFICADO':'CODIGO_CERTIFICADO', 'CNAE':'CODIGO_DESCRICAO_CNAE',   'NATUREZA JURÍDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201901_t2 = df_201901_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA DE INICIO DA OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'DATA DE GERAÇÃO DO CERTIFICADO':'DATA_GERACAO_CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO':'DATA_VALIDADE_CERTIFICADO', 'CÓDIGO DO CERTIFICADO':'CODIGO_CERTIFICADO', 'CNAE':'CODIGO_DESCRICAO_CNAE',   'NATUREZA JURÍDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201902_t2 = df_201902_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA DE INICIO DA OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'DATA DE GERAÇÃO DO CERTIFICADO':'DATA_GERACAO_CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO':'DATA_VALIDADE_CERTIFICADO', 'CÓDIGO DO CERTIFICADO':'CODIGO_CERTIFICADO', 'CNAE':'CODIGO_DESCRICAO_CNAE',   'NATUREZA JURÍDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201903_t2 = df_201903_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA DE INICIO DA OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'DATA DE GERAÇÃO DO CERTIFICADO':'DATA_GERACAO_CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO':'DATA_VALIDADE_CERTIFICADO', 'CÓDIGO DO CERTIFICADO':'CODIGO_CERTIFICADO', 'CNAE':'CODIGO_DESCRICAO_CNAE',   'NATUREZA JURÍDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201904_t2 = df_201904_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA DE INICIO DA OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'DATA DE GERAÇÃO DO CERTIFICADO':'DATA_GERACAO_CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO':'DATA_VALIDADE_CERTIFICADO', 'CÓDIGO DO CERTIFICADO':'CODIGO_CERTIFICADO', 'CNAE':'CODIGO_DESCRICAO_CNAE',   'NATUREZA JURÍDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201804_t2 = df_201804_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA DE INICIO DA OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'DATA DE GERAÇÃO DO CERTIFICADO':'DATA_GERACAO_CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO':'DATA_VALIDADE_CERTIFICADO', 'CÓDIGO DO CERTIFICADO':'CODIGO_CERTIFICADO', 'CNAE':'CODIGO_DESCRICAO_CNAE',   'NATUREZA JURÍDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201803_t2 = df_201803_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA DE INICIO DA OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'DATA DE GERAÇÃO DO CERTIFICADO':'DATA_GERACAO_CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO':'DATA_VALIDADE_CERTIFICADO', 'CÓDIGO DO CERTIFICADO':'CODIGO_CERTIFICADO', 'CNAE':'CODIGO_DESCRICAO_CNAE',   'NATUREZA JURÍDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201802_t2 = df_201802_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA DE INICIO DA OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'DATA DE GERAÇÃO DO CERTIFICADO':'DATA_GERACAO_CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO':'DATA_VALIDADE_CERTIFICADO', 'CÓDIGO DO CERTIFICADO':'CODIGO_CERTIFICADO', 'CNAE':'CODIGO_DESCRICAO_CNAE',   'NATUREZA JURÍDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201801_t2 = df_201801_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA DE INICIO DA OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'DATA DE GERAÇÃO DO CERTIFICADO':'DATA_GERACAO_CERTIFICADO', 'DATA DE VALIDADE DO CERTIFICADO':'DATA_VALIDADE_CERTIFICADO', 'CÓDIGO DO CERTIFICADO':'CODIGO_CERTIFICADO', 'CNAE':'CODIGO_DESCRICAO_CNAE',   'NATUREZA JURÍDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201704_t2 = df_201704_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA INICIO OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'TIPO ATIVIDADE':'ATIVIDADE','CÓDIGO CERTIFICADO':'CODIGO_CERTIFICADO', 'CÓDIGO E DESCRIÇÃO CNAE':'CODIGO_DESCRICAO_CNAE',  'NATUREZA JURIDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201703_t2 = df_201703_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA INICIO OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'TIPO ATIVIDADE':'ATIVIDADE','CÓDIGO CERTIFICADO':'CODIGO_CERTIFICADO', 'CÓDIGO E DESCRIÇÃO CNAE':'CODIGO_DESCRICAO_CNAE',  'NATUREZA JURIDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201702_t2 = df_201702_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA INICIO OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'TIPO ATIVIDADE':'ATIVIDADE','CÓDIGO CERTIFICADO':'CODIGO_CERTIFICADO', 'CÓDIGO E DESCRIÇÃO CNAE':'CODIGO_DESCRICAO_CNAE',  'NATUREZA JURIDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201701_t2 = df_201701_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA INICIO OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'TIPO ATIVIDADE':'ATIVIDADE','CÓDIGO CERTIFICADO':'CODIGO_CERTIFICADO', 'CÓDIGO E DESCRIÇÃO CNAE':'CODIGO_DESCRICAO_CNAE',  'NATUREZA JURIDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201604_t2 = df_201604_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA INICIO OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'TIPO ATIVIDADE':'ATIVIDADE','CÓDIGO CERTIFICADO':'CODIGO_CERTIFICADO', 'CÓDIGO E DESCRIÇÃO CNAE':'CODIGO_DESCRICAO_CNAE',  'NATUREZA JURIDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201603_t2 = df_201603_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA INICIO OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'TIPO ATIVIDADE':'ATIVIDADE','CÓDIGO CERTIFICADO':'CODIGO_CERTIFICADO', 'CÓDIGO E DESCRIÇÃO CNAE':'CODIGO_DESCRICAO_CNAE',  'NATUREZA JURIDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201602_t2 = df_201602_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA INICIO OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'TIPO ATIVIDADE':'ATIVIDADE','DATA GERAÇÃO CERTIFICADO'     :'DATA_GERACAO_CERTIFICADO', 'DATA VALIDADE CERTIFICADO':'DATA_VALIDADE_CERTIFICADO', 'CÓDIGO CERTIFICADO':'CODIGO_CERTIFICADO', 'CÓDIGO E DESCRIÇÃO CNAE':'CODIGO_DESCRICAO_CNAE',  'NATUREZA JURIDICA':"NATUREZA_JURIDICA"})[select_columns]
df_201601_t2 = df_201601_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA INICIO OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'TIPO ATIVIDADE':'ATIVIDADE','DATA GERAÇÃO CERTIFICADO'     :'DATA_GERACAO_CERTIFICADO', 'DATA VALIDADE CERTIFICADO':'DATA_VALIDADE_CERTIFICADO', 'CÓDIGO CERTIFICADO':'CODIGO_CERTIFICADO', 'CÓDIGO E DESCRIÇÃO CNAE':'CODIGO_DESCRICAO_CNAE',  'NATUREZA JURIDICA':"NATUREZA_JURIDICA"})[select_columns]
df_2015_t2 = df_2015_t.rename(columns={'RAZÃO SOCIAL':"RAZAO_SOCIAL", 'NOME FANTASIA':'NOME_FANTASIA', 'DATA INICIO OPERAÇÃO':'DATA_INICIO_OPERACAO', 'SITUAÇÃO':'SITUACAO', 'TIPO ATIVIDADE':'ATIVIDADE','CÓDIGO CERTIFICADO':'CODIGO_CERTIFICADO', 'CÓDIGO E DESCRIÇÃO CNAE':'CODIGO_DESCRICAO_CNAE',  'NATUREZA JURIDICA':"NATUREZA_JURIDICA"})[select_columns]

# %%
print('202101',df_202101_t2.columns,'\n')
print('202004',df_202004_t2.columns,'\n')
print('202003',df_202003_t2.columns,'\n')
print('202001',df_202001_t2.columns,'\n')
print('201901',df_201901_t2.columns,'\n')
print('201902',df_201902_t2.columns,'\n')
print('201903',df_201903_t2.columns,'\n')
print('201904',df_201904_t2.columns,'\n')
print('201804',df_201804_t2.columns,'\n')
print('201803',df_201803_t2.columns,'\n')
print('201802',df_201802_t2.columns,'\n')
print('201801',df_201801_t2.columns,'\n')
print('201704',df_201704_t2.columns,'\n')
print('201703',df_201703_t2.columns,'\n')
print('201702',df_201702_t2.columns,'\n')
print('201701',df_201701_t2.columns,'\n')
print('201604',df_201604_t2.columns,'\n')
print('201603',df_201603_t2.columns,'\n')
print('201602',df_201602_t2.columns,'\n')
print('201601',df_201601_t2.columns,'\n')
print('2015_t',df_2015_t2.columns,'\n')
# Out:
# 202101 Index(['ANO', 'TRIMESTRE', 'RAZAO_SOCIAL', 'NOME_FANTASIA', 'CNPJ', 'PORTE', 'DATA_INICIO_OPERACAO', 'SITUACAO', 'ATIVIDADE', 'CEP', 'UF', 'LOCALIDADE', 'BAIRRO', 'LOGRADOURO', 'DATA_GERACAO_CERTIFICADO', 'DATA_VALIDADE_CERTIFICADO', 'CODIGO_CERTIFICADO', 'CODIGO_DESCRICAO_CNAE', 'NATUREZA_JURIDICA'], dtype='object')
#
# 202004 Index(['ANO', 'TRIMESTRE', 'RAZAO_SOCIAL', 'NOME_FANTASIA', 'CNPJ', 'PORTE', 'DATA_INICIO_OPERACAO', 'SITUACAO', 'ATIVIDADE', 'CEP', 'UF', 'LOCALIDADE', 'BAIRRO', 'LOGRADOURO', 'DATA_GERACAO_CERTIFICADO', 'DATA_VALIDADE_CERTIFICADO', 'CODIGO_CERTIFICADO', 'CODIGO_DESCRICAO_CNAE', 'NATUREZA_JURIDICA'], dtype='object')
#
# 202003 Index(['ANO', 'TRIMESTRE', 'RAZAO_SOCIAL', 'NOME_FANTASIA', 'CNPJ', 'PORTE', 'DATA_INICIO_OPERACAO', 'SITUACAO', 'ATIVIDADE', 'CEP', 'UF', 'LOCALIDADE', 'BAIRRO', 'LOGRADOURO', 'DATA_GERACAO_CERTIFICADO', 'DATA_VALIDADE_CERTIFICADO', 'CODIGO_CERTIFICADO', 'CODIGO_DESCRICAO_CNAE', 'NATUREZA_JURIDICA'], dtype='object')
#
# ...

# %%
df_2015_t2.head(2)
# Out:
#     ANO  TRIMESTRE                             RAZAO_SOCIAL                  NOME_FANTASIA                CNPJ         PORTE DATA_INICIO_OPERACAO     SITUACAO                         ATIVIDADE       CEP  UF    LOCALIDADE                    BAIRRO                                         LOGRADOURO  DATA_GERACAO_CERTIFICADO  DATA_VALIDADE_CERTIFICADO   CODIGO_CERTIFICADO                              CODIGO_DESCRICAO_CNAE     NATUREZA_JURIDICA
# 0  2015          0  14 BIS CHOPERIA E RESTAURANTE LTDA - ME  14 BIS CHOPERIA E RESTAURANTE  23.797.856/0001-35  Microempresa                  NaN  Em Operação  Restaurantes, Cafeterias e Bares  76270000  GO       Jussara                   Jussara  AV. MARECHAL RONDON SN QD. 02 LT. 02 SETOR AER...                       NaN                        NaN  09.075781.15.0001-2  5611-2/01-RESTAURANTES E SIMILARES (Primário),...  Sociedade Empresária
# ...

# %%
print('202101 ', df_202101_t2.dtypes,'\n')
print('202004 ', df_202004_t2.dtypes,'\n')
print('202003 ', df_202003_t2.dtypes,'\n')
print('202001 ', df_202001_t2.dtypes,'\n')
print('201901 ', df_201901_t2.dtypes,'\n')
print('201902 ', df_201902_t2.dtypes,'\n')
print('201903 ', df_201903_t2.dtypes,'\n')
print('201904 ', df_201904_t2.dtypes,'\n')
print('201804 ', df_201804_t2.dtypes,'\n')
print('201803 ', df_201803_t2.dtypes,'\n')
print('201802 ', df_201802_t2.dtypes,'\n')
print('201801 ', df_201801_t2.dtypes,'\n')
print('201704 ', df_201704_t2.dtypes,'\n')
print('201703 ', df_201703_t2.dtypes,'\n')
print('201702 ', df_201702_t2.dtypes,'\n')
print('201701 ', df_201701_t2.dtypes,'\n')
print('201604 ', df_201604_t2.dtypes,'\n')
print('201603 ', df_201603_t2.dtypes,'\n')
print('201602 ', df_201602_t2.dtypes,'\n')
print('201601 ', df_201601_t2.dtypes,'\n')
print('2015_t ', df_2015_t2.dtypes,'\n')
# Out:
# 202101  ANO                           int64
# TRIMESTRE                     int64
# RAZAO_SOCIAL                 object
# NOME_FANTASIA                object
# CNPJ                         object
# PORTE                        object
# DATA_INICIO_OPERACAO         object
# SITUACAO                     object
# ATIVIDADE                    object
# CEP                          object
# UF                           object
# LOCALIDADE                   object
# BAIRRO                       object
# LOGRADOURO                   object
# DATA_GERACAO_CERTIFICADO     object
# DATA_VALIDADE_CERTIFICADO    object
# CODIGO_CERTIFICADO           object
# CODIGO_DESCRICAO_CNAE        object
# NATUREZA_JURIDICA            object
# dtype: object
#
# 202004  ANO                           int64
# TRIMESTRE                     int64
# RAZAO_SOCIAL                 object
# NOME_FANTASIA                object
# CNPJ                         object
# PORTE                        object
# ...

# %%
#{'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP', 'UF', 'LOCALIDADE', 'BAIRRO', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'}

# %% [markdown]
# Definindo ***DTYPES*** padronizados para todas as tabelas

# %%
df_202101_t3 = df_202101_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_202004_t3 = df_202004_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_202003_t3 = df_202003_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_202001_t3 = df_202001_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201901_t3 = df_201901_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201902_t3 = df_201902_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201903_t3 = df_201903_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201904_t3 = df_201904_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201804_t3 = df_201804_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201803_t3 = df_201803_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201802_t3 = df_201802_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201801_t3 = df_201801_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201704_t3 = df_201704_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201703_t3 = df_201703_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201702_t3 = df_201702_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201701_t3 = df_201701_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201604_t3 = df_201604_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201603_t3 = df_201603_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201602_t3 = df_201602_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_201601_t3 = df_201601_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})
df_2015_t3   = df_2015_t2.astype({'ANO':'int','TRIMESTRE':'int','RAZAO_SOCIAL':'object','NOME_FANTASIA':'object','CNPJ':'object','PORTE':'object','DATA_INICIO_OPERACAO':'object','SITUACAO':'object','ATIVIDADE':'object','CEP':'object', 'UF':'object', 'LOCALIDADE':'object', 'BAIRRO':'object', 'LOGRADOURO':'object','DATA_GERACAO_CERTIFICADO':'object', 'DATA_VALIDADE_CERTIFICADO':'object','CODIGO_CERTIFICADO':'object','CODIGO_DESCRICAO_CNAE':'object','NATUREZA_JURIDICA':'object'})

# %% [markdown]
# Unificação das ***TABELAS***

# %%
df_union = [df_202101_t3,df_202004_t3,df_202003_t3,df_202001_t3,df_201901_t3,df_201902_t3,df_201903_t3,df_201904_t3,df_201804_t3,df_201803_t3,df_201802_t3,df_201801_t3,df_201704_t3,df_201703_t3,
df_201702_t3,df_201701_t3,df_201604_t3,df_201603_t3,df_201602_t3,df_201601_t3,df_2015_t3]

df_final = pd.concat(df_union)

# %%
df_final.count()
# Out:
# ANO                          84155
# TRIMESTRE                    84155
# RAZAO_SOCIAL                 84155
# NOME_FANTASIA                84121
# CNPJ                         84155
# PORTE                        84155
# DATA_INICIO_OPERACAO         71397
# SITUACAO                     84155
# ATIVIDADE                    84155
# CEP                          84155
# UF                           84155
# LOCALIDADE                   84155
# BAIRRO                       84155
# LOGRADOURO                   84033
# DATA_GERACAO_CERTIFICADO     72632
# DATA_VALIDADE_CERTIFICADO    72632
# CODIGO_CERTIFICADO           84155
# CODIGO_DESCRICAO_CNAE        84155
# NATUREZA_JURIDICA            84155
# dtype: int64

# %%
df_final.query("UF == 'PE'")
# Out:
#        ANO  TRIMESTRE                                       RAZAO_SOCIAL                         NOME_FANTASIA                CNPJ                     PORTE DATA_INICIO_OPERACAO     SITUACAO                                ATIVIDADE        CEP  UF          LOCALIDADE       BAIRRO                                        LOGRADOURO DATA_GERACAO_CERTIFICADO DATA_VALIDADE_CERTIFICADO   CODIGO_CERTIFICADO                              CODIGO_DESCRICAO_CNAE                                  NATUREZA_JURIDICA
# ...

# %% [markdown]
# Pegando os ***COMERCIOS*** relacionados a ***PE*** , e futuramente utilizar somente as regiões em comum com os outros ***DATASET's***

# %%
df_final_pe = df_final.query("UF == 'PE'")

# %%
df_final_pe.count()
# Out:
# ANO                          1230
# TRIMESTRE                    1230
# RAZAO_SOCIAL                 1230
# NOME_FANTASIA                1230
# CNPJ                         1230
# PORTE                        1230
# DATA_INICIO_OPERACAO         1086
# SITUACAO                     1230
# ATIVIDADE                    1230
# CEP                          1230
# UF                           1230
# LOCALIDADE                   1230
# BAIRRO                       1230
# LOGRADOURO                   1230
# DATA_GERACAO_CERTIFICADO     1107
# DATA_VALIDADE_CERTIFICADO    1107
# CODIGO_CERTIFICADO           1230
# CODIGO_DESCRICAO_CNAE        1230
# NATUREZA_JURIDICA            1230
# dtype: int64

# %%
df_final_pe.head(2)
# Out:
#       ANO  TRIMESTRE                       RAZAO_SOCIAL                         NOME_FANTASIA                CNPJ                     PORTE DATA_INICIO_OPERACAO     SITUACAO                                ATIVIDADE        CEP  UF          LOCALIDADE     BAIRRO                            LOGRADOURO DATA_GERACAO_CERTIFICADO DATA_VALIDADE_CERTIFICADO  CODIGO_CERTIFICADO                              CODIGO_DESCRICAO_CNAE              NATUREZA_JURIDICA
# 165  2021          1        MELLO, RIBEIRO & MELLO LTDA                China in Box Rosarinho  00.874.830/0001-48  EMPRESA DE PEQUENO PORTE           25/10/1995  Em Operação  Restaurante, Cafeteria, Bar e Similares  52041-305  PE              Recife  Rosarinho                        Amaro Coutinho         23/03/2020 09:27          23/03/2022 09:27  00.874.830/0001-48  5611-2/03 - LANCHONETES, CASAS DE CHÁ, DE SUCO...  Sociedade Empresária Limitada
# ...

# %% [markdown]
# Salvando ***TABELA***

# %%
df_final_pe.to_csv(r'comercios_2015_2021_trimestre.csv', sep=';', index = False)
